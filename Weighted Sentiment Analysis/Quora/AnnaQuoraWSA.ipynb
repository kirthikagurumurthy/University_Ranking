# %%
import json
import csv
#import tweepy
import re
import nltk
from nltk.stem import WordNetLemmatizer
import pandas as pd
#import GetOldTweets3 as got
from nltk.corpus import stopwords
stopwords = set(stopwords.words('english'))
lemmatizer = WordNetLemmatizer()
import numpy as np
from nltk import tokenize
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
nltk.download("punkt")
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Kirthika\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
df=pd.read_csv('../../Datasets/Quora/Data/AnnaUniQuora.csv')

#df = df.dropna()

# %%
df
# Out:
#       Unnamed: 0                             Topic  \
# 0              0  Anna-University-Tamil-Nadu-India
# 1              1  Anna-University-Tamil-Nadu-India
# 2              2  Anna-University-Tamil-Nadu-India
# 3              3  Anna-University-Tamil-Nadu-India
# 4              4  Anna-University-Tamil-Nadu-India
# ...          ...                               ...
# 1332        1332  Anna-University-Tamil-Nadu-India
# 1333        1333  Anna-University-Tamil-Nadu-India
# 1334        1334  Anna-University-Tamil-Nadu-India
# 1335        1335  Anna-University-Tamil-Nadu-India
# 1336        1336  Anna-University-Tamil-Nadu-India
#
#                                                question  Followers  Answers  \
# 0     Will I get CEG College in Chennai for the cuto...          1        2
# 1     Will I get CEG College in Chennai for the cuto...          1        2
# 2     What is the expected cutoff for Anna universit...          2        1
# 3     Apart from Anna University what are the top 10...          3        3
# 4     Apart from Anna University what are the top 10...          3        3
# ...                                                 ...        ...      ...
# 1332  What is the procedure for an OCI holder to get...          0        1
# 1333  Can I be placed in campus if I study in the An...          2        1
# 1334  What is the cutoff mark to get into CEG Anna U...          1        5
# 1335  What is the cutoff mark to get into CEG Anna U...          1        5
# 1336  Can students transfer from an autonomous colle...          1        1
#
#      Ratio Engagement potential Last action Parsed time  \
# 0      1/2                   No    Followed  2020-08-02
# 1      1/2                   No    Followed  2020-08-02
# 2      2/1                   No    Followed  2020-08-02
# 3      3/3                   No    Followed  2020-08-02
# 4      3/3                   No    Followed  2020-08-02
# ...    ...                  ...         ...         ...
# 1332   0/1                   No   Requested  2018-02-18
# 1333   2/1                   No    Followed  2018-02-19
# 1334   1/5                   No   Requested  2018-02-18
# 1335   1/5                   No   Requested  2018-02-18
# 1336   1/1                   No    Followed  2018-02-17
#
#                                           Question link  \
# 0     https://www.quora.com/Will-I-get-CEG-College-i...
# 1     https://www.quora.com/Will-I-get-CEG-College-i...
# 2     https://www.quora.com/What-is-the-expected-cut...
# 3     https://www.quora.com/Apart-from-Anna-Universi...
# 4     https://www.quora.com/Apart-from-Anna-Universi...
# ...                                                 ...
# 1332  https://www.quora.com/What-is-the-procedure-fo...
# 1333  https://www.quora.com/Can-I-be-placed-in-campu...
# 1334  https://www.quora.com/What-is-the-cutoff-mark-...
# 1335  https://www.quora.com/What-is-the-cutoff-mark-...
# 1336  https://www.quora.com/Can-students-transfer-fr...
#
#                                                 answers
# 0     Yes definitely u will get CEG, ACT, MIT, SSN. ...
# 1     With this cutoff. U won't get any top branches...
# 2                                  Same qus for me too
# 3     Top 10 Engineering Autonomous Colleges in Chen...
# 4     VIT vellore, SSN is currently the best autonom...
# ...                                                 ...
# 1332  Admission process is explained below.. Admissi...
# 1333  Yes you can, also depends on the number of arr...
# 1334  You can take a look at this, UNIVERSITY DEPART...
# 1335  Primarily, it depends on your community. The r...
# 1336   Depends on vacancy and respective college rules
#
# [1337 rows x 11 columns]

# %%
df=df.reset_index()

# %%
df=df.drop_duplicates()

# %%
df=df.drop(['index'],axis=1)

# %%
def vader_score(paragraph):
    analyzer = SentimentIntensityAnalyzer()
    paragraphSentiments = 0.0
    avg = -1
    sentence_list = tokenize.sent_tokenize(paragraph)
    size = len(sentence_list)
    #print(len((sentence_list))
    for sentence in sentence_list :
        vs = analyzer.polarity_scores(sentence)
        paragraphSentiments += vs["compound"]
    if( size == 0):
        print("zero")
    else:
        avg = (paragraphSentiments / size)
    return avg

# %%
df['compound'] = df['answers'].apply(lambda x: vader_score(x))
# Out:
# zero
# zero

# %%
i = df[df['compound'] == -1].index
df.drop(i)
# Out:
#       Unnamed: 0                             Topic  \
# 0              0  Anna-University-Tamil-Nadu-India
# 1              1  Anna-University-Tamil-Nadu-India
# 2              2  Anna-University-Tamil-Nadu-India
# 3              3  Anna-University-Tamil-Nadu-India
# 4              4  Anna-University-Tamil-Nadu-India
# ...          ...                               ...
# 1332        1332  Anna-University-Tamil-Nadu-India
# 1333        1333  Anna-University-Tamil-Nadu-India
# 1334        1334  Anna-University-Tamil-Nadu-India
# 1335        1335  Anna-University-Tamil-Nadu-India
# 1336        1336  Anna-University-Tamil-Nadu-India
#
#                                                question  Followers  Answers  \
# 0     Will I get CEG College in Chennai for the cuto...          1        2
# 1     Will I get CEG College in Chennai for the cuto...          1        2
# 2     What is the expected cutoff for Anna universit...          2        1
# 3     Apart from Anna University what are the top 10...          3        3
# 4     Apart from Anna University what are the top 10...          3        3
# ...                                                 ...        ...      ...
# 1332  What is the procedure for an OCI holder to get...          0        1
# 1333  Can I be placed in campus if I study in the An...          2        1
# 1334  What is the cutoff mark to get into CEG Anna U...          1        5
# 1335  What is the cutoff mark to get into CEG Anna U...          1        5
# 1336  Can students transfer from an autonomous colle...          1        1
#
#      Ratio Engagement potential Last action Parsed time  \
# 0      1/2                   No    Followed  2020-08-02
# 1      1/2                   No    Followed  2020-08-02
# 2      2/1                   No    Followed  2020-08-02
# 3      3/3                   No    Followed  2020-08-02
# 4      3/3                   No    Followed  2020-08-02
# ...    ...                  ...         ...         ...
# 1332   0/1                   No   Requested  2018-02-18
# 1333   2/1                   No    Followed  2018-02-19
# 1334   1/5                   No   Requested  2018-02-18
# 1335   1/5                   No   Requested  2018-02-18
# 1336   1/1                   No    Followed  2018-02-17
#
#                                           Question link  \
# 0     https://www.quora.com/Will-I-get-CEG-College-i...
# 1     https://www.quora.com/Will-I-get-CEG-College-i...
# 2     https://www.quora.com/What-is-the-expected-cut...
# 3     https://www.quora.com/Apart-from-Anna-Universi...
# 4     https://www.quora.com/Apart-from-Anna-Universi...
# ...                                                 ...
# 1332  https://www.quora.com/What-is-the-procedure-fo...
# 1333  https://www.quora.com/Can-I-be-placed-in-campu...
# 1334  https://www.quora.com/What-is-the-cutoff-mark-...
# 1335  https://www.quora.com/What-is-the-cutoff-mark-...
# 1336  https://www.quora.com/Can-students-transfer-fr...
#
#                                                 answers  compound
# 0     Yes definitely u will get CEG, ACT, MIT, SSN. ...  0.707600
# 1     With this cutoff. U won't get any top branches...  0.196500
# 2                                  Same qus for me too   0.000000
# 3     Top 10 Engineering Autonomous Colleges in Chen...  0.025288
# 4     VIT vellore, SSN is currently the best autonom...  0.318450
# ...                                                 ...       ...
# 1332  Admission process is explained below.. Admissi...  0.046626
# 1333  Yes you can, also depends on the number of arr...  0.185286
# 1334  You can take a look at this, UNIVERSITY DEPART...  0.190633
# 1335  Primarily, it depends on your community. The r...  0.222180
# 1336   Depends on vacancy and respective college rules   0.421500
#
# [1335 rows x 12 columns]

# %%
#classifying sentiments as positive,negative and neutral
def sentiment(compound):
    res = ""
    if(compound >= 0.05):
        res="Positive"
    elif(compound <= - 0.05):
        res="Negative"
    else:
        res="Neutral"
    return res

df['Sentiment'] = df['compound'].apply(lambda x: sentiment(x))

# %%
df
# Out:
#       Unnamed: 0                             Topic  \
# 0              0  Anna-University-Tamil-Nadu-India
# 1              1  Anna-University-Tamil-Nadu-India
# 2              2  Anna-University-Tamil-Nadu-India
# 3              3  Anna-University-Tamil-Nadu-India
# 4              4  Anna-University-Tamil-Nadu-India
# ...          ...                               ...
# 1332        1332  Anna-University-Tamil-Nadu-India
# 1333        1333  Anna-University-Tamil-Nadu-India
# 1334        1334  Anna-University-Tamil-Nadu-India
# 1335        1335  Anna-University-Tamil-Nadu-India
# 1336        1336  Anna-University-Tamil-Nadu-India
#
#                                                question  Followers  Answers  \
# 0     Will I get CEG College in Chennai for the cuto...          1        2
# 1     Will I get CEG College in Chennai for the cuto...          1        2
# 2     What is the expected cutoff for Anna universit...          2        1
# 3     Apart from Anna University what are the top 10...          3        3
# 4     Apart from Anna University what are the top 10...          3        3
# ...                                                 ...        ...      ...
# 1332  What is the procedure for an OCI holder to get...          0        1
# 1333  Can I be placed in campus if I study in the An...          2        1
# 1334  What is the cutoff mark to get into CEG Anna U...          1        5
# 1335  What is the cutoff mark to get into CEG Anna U...          1        5
# 1336  Can students transfer from an autonomous colle...          1        1
#
#      Ratio Engagement potential Last action Parsed time  \
# 0      1/2                   No    Followed  2020-08-02
# 1      1/2                   No    Followed  2020-08-02
# 2      2/1                   No    Followed  2020-08-02
# 3      3/3                   No    Followed  2020-08-02
# 4      3/3                   No    Followed  2020-08-02
# ...    ...                  ...         ...         ...
# 1332   0/1                   No   Requested  2018-02-18
# 1333   2/1                   No    Followed  2018-02-19
# 1334   1/5                   No   Requested  2018-02-18
# 1335   1/5                   No   Requested  2018-02-18
# 1336   1/1                   No    Followed  2018-02-17
#
#                                           Question link  \
# 0     https://www.quora.com/Will-I-get-CEG-College-i...
# 1     https://www.quora.com/Will-I-get-CEG-College-i...
# 2     https://www.quora.com/What-is-the-expected-cut...
# 3     https://www.quora.com/Apart-from-Anna-Universi...
# 4     https://www.quora.com/Apart-from-Anna-Universi...
# ...                                                 ...
# 1332  https://www.quora.com/What-is-the-procedure-fo...
# 1333  https://www.quora.com/Can-I-be-placed-in-campu...
# 1334  https://www.quora.com/What-is-the-cutoff-mark-...
# 1335  https://www.quora.com/What-is-the-cutoff-mark-...
# 1336  https://www.quora.com/Can-students-transfer-fr...
#
#                                                 answers  compound Sentiment
# 0     Yes definitely u will get CEG, ACT, MIT, SSN. ...  0.707600  Positive
# 1     With this cutoff. U won't get any top branches...  0.196500  Positive
# 2                                  Same qus for me too   0.000000   Neutral
# 3     Top 10 Engineering Autonomous Colleges in Chen...  0.025288   Neutral
# 4     VIT vellore, SSN is currently the best autonom...  0.318450  Positive
# ...                                                 ...       ...       ...
# 1332  Admission process is explained below.. Admissi...  0.046626   Neutral
# 1333  Yes you can, also depends on the number of arr...  0.185286  Positive
# 1334  You can take a look at this, UNIVERSITY DEPART...  0.190633  Positive
# 1335  Primarily, it depends on your community. The r...  0.222180  Positive
# 1336   Depends on vacancy and respective college rules   0.421500  Positive
#
# [1337 rows x 13 columns]

# %%
def convert(score):
    OldRange = 2  
    NewRange = 4  
    NewValue = (((score + 1) * NewRange) / OldRange) + 1
    return NewValue
df['score'] = df['compound'].apply(lambda x: convert(x))
df
def assignpred(n):
    if n>1 and n<3:
        return max((n-1),1)
    if n>3 and n<5:
        return min((n+1),5)

# %%
def normalize(feature):
    max_value = df[feature].max()
    min_value = df[feature].min()
    result = (df[feature] - min_value) / (max_value - min_value)
    return result

# %%
df['followers_n']=normalize('Followers')

# %%
df
# Out:
#       Unnamed: 0                             Topic  \
# 0              0  Anna-University-Tamil-Nadu-India
# 1              1  Anna-University-Tamil-Nadu-India
# 2              2  Anna-University-Tamil-Nadu-India
# 3              3  Anna-University-Tamil-Nadu-India
# 4              4  Anna-University-Tamil-Nadu-India
# ...          ...                               ...
# 1332        1332  Anna-University-Tamil-Nadu-India
# 1333        1333  Anna-University-Tamil-Nadu-India
# 1334        1334  Anna-University-Tamil-Nadu-India
# 1335        1335  Anna-University-Tamil-Nadu-India
# 1336        1336  Anna-University-Tamil-Nadu-India
#
#                                                question  Followers  Answers  \
# 0     Will I get CEG College in Chennai for the cuto...          1        2
# 1     Will I get CEG College in Chennai for the cuto...          1        2
# 2     What is the expected cutoff for Anna universit...          2        1
# 3     Apart from Anna University what are the top 10...          3        3
# 4     Apart from Anna University what are the top 10...          3        3
# ...                                                 ...        ...      ...
# 1332  What is the procedure for an OCI holder to get...          0        1
# 1333  Can I be placed in campus if I study in the An...          2        1
# 1334  What is the cutoff mark to get into CEG Anna U...          1        5
# 1335  What is the cutoff mark to get into CEG Anna U...          1        5
# 1336  Can students transfer from an autonomous colle...          1        1
#
#      Ratio Engagement potential Last action Parsed time  \
# 0      1/2                   No    Followed  2020-08-02
# 1      1/2                   No    Followed  2020-08-02
# 2      2/1                   No    Followed  2020-08-02
# 3      3/3                   No    Followed  2020-08-02
# 4      3/3                   No    Followed  2020-08-02
# ...    ...                  ...         ...         ...
# 1332   0/1                   No   Requested  2018-02-18
# 1333   2/1                   No    Followed  2018-02-19
# 1334   1/5                   No   Requested  2018-02-18
# 1335   1/5                   No   Requested  2018-02-18
# 1336   1/1                   No    Followed  2018-02-17
#
#                                           Question link  \
# 0     https://www.quora.com/Will-I-get-CEG-College-i...
# 1     https://www.quora.com/Will-I-get-CEG-College-i...
# 2     https://www.quora.com/What-is-the-expected-cut...
# 3     https://www.quora.com/Apart-from-Anna-Universi...
# 4     https://www.quora.com/Apart-from-Anna-Universi...
# ...                                                 ...
# 1332  https://www.quora.com/What-is-the-procedure-fo...
# 1333  https://www.quora.com/Can-I-be-placed-in-campu...
# 1334  https://www.quora.com/What-is-the-cutoff-mark-...
# 1335  https://www.quora.com/What-is-the-cutoff-mark-...
# 1336  https://www.quora.com/Can-students-transfer-fr...
#
#                                                 answers  compound Sentiment  \
# 0     Yes definitely u will get CEG, ACT, MIT, SSN. ...  0.707600  Positive
# 1     With this cutoff. U won't get any top branches...  0.196500  Positive
# 2                                  Same qus for me too   0.000000   Neutral
# 3     Top 10 Engineering Autonomous Colleges in Chen...  0.025288   Neutral
# 4     VIT vellore, SSN is currently the best autonom...  0.318450  Positive
# ...                                                 ...       ...       ...
# 1332  Admission process is explained below.. Admissi...  0.046626   Neutral
# 1333  Yes you can, also depends on the number of arr...  0.185286  Positive
# 1334  You can take a look at this, UNIVERSITY DEPART...  0.190633  Positive
# 1335  Primarily, it depends on your community. The r...  0.222180  Positive
# 1336   Depends on vacancy and respective college rules   0.421500  Positive
#
#          score  followers_n
# 0     4.415200     0.032258
# 1     3.393000     0.032258
# 2     3.000000     0.064516
# 3     3.050575     0.096774
# 4     3.636900     0.096774
# ...        ...          ...
# 1332  3.093252     0.000000
# 1333  3.370571     0.064516
# 1334  3.381267     0.032258
# 1335  3.444360     0.032258
# 1336  3.843000     0.032258
#
# [1337 rows x 15 columns]

# %%
engagement_median = df['followers_n'].median()
df["engagement"] = df['followers_n'].apply(lambda x: 1 if x >= engagement_median else 0)

# %%
df['sentiment_score']=df['score']
df_eng1=df[df.engagement==1]
#if engagement score is greater than the median, increase the positive and negative sentiment
df_eng1['sentiment_score']=df_eng1['score'].apply(lambda x: assignpred(x))
df[df.engagement==1]=df_eng1
df
# Out:
# C:\Users\Kirthika\anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
#       Unnamed: 0                             Topic  \
# 0              0  Anna-University-Tamil-Nadu-India
# 1              1  Anna-University-Tamil-Nadu-India
# 2              2  Anna-University-Tamil-Nadu-India
# 3              3  Anna-University-Tamil-Nadu-India
# 4              4  Anna-University-Tamil-Nadu-India
# ...          ...                               ...
# 1332        1332  Anna-University-Tamil-Nadu-India
# 1333        1333  Anna-University-Tamil-Nadu-India
# 1334        1334  Anna-University-Tamil-Nadu-India
# 1335        1335  Anna-University-Tamil-Nadu-India
# 1336        1336  Anna-University-Tamil-Nadu-India
#
#                                                question  Followers  Answers  \
# 0     Will I get CEG College in Chennai for the cuto...          1        2
# 1     Will I get CEG College in Chennai for the cuto...          1        2
# 2     What is the expected cutoff for Anna universit...          2        1
# 3     Apart from Anna University what are the top 10...          3        3
# 4     Apart from Anna University what are the top 10...          3        3
# ...                                                 ...        ...      ...
# 1332  What is the procedure for an OCI holder to get...          0        1
# 1333  Can I be placed in campus if I study in the An...          2        1
# 1334  What is the cutoff mark to get into CEG Anna U...          1        5
# 1335  What is the cutoff mark to get into CEG Anna U...          1        5
# 1336  Can students transfer from an autonomous colle...          1        1
#
#      Ratio Engagement potential Last action Parsed time  \
# 0      1/2                   No    Followed  2020-08-02
# 1      1/2                   No    Followed  2020-08-02
# 2      2/1                   No    Followed  2020-08-02
# 3      3/3                   No    Followed  2020-08-02
# 4      3/3                   No    Followed  2020-08-02
# ...    ...                  ...         ...         ...
# 1332   0/1                   No   Requested  2018-02-18
# 1333   2/1                   No    Followed  2018-02-19
# 1334   1/5                   No   Requested  2018-02-18
# 1335   1/5                   No   Requested  2018-02-18
# 1336   1/1                   No    Followed  2018-02-17
#
#                                           Question link  \
# 0     https://www.quora.com/Will-I-get-CEG-College-i...
# 1     https://www.quora.com/Will-I-get-CEG-College-i...
# 2     https://www.quora.com/What-is-the-expected-cut...
# 3     https://www.quora.com/Apart-from-Anna-Universi...
# 4     https://www.quora.com/Apart-from-Anna-Universi...
# ...                                                 ...
# 1332  https://www.quora.com/What-is-the-procedure-fo...
# 1333  https://www.quora.com/Can-I-be-placed-in-campu...
# 1334  https://www.quora.com/What-is-the-cutoff-mark-...
# 1335  https://www.quora.com/What-is-the-cutoff-mark-...
# 1336  https://www.quora.com/Can-students-transfer-fr...
#
#                                                 answers  compound Sentiment  \
# 0     Yes definitely u will get CEG, ACT, MIT, SSN. ...  0.707600  Positive
# 1     With this cutoff. U won't get any top branches...  0.196500  Positive
# 2                                  Same qus for me too   0.000000   Neutral
# 3     Top 10 Engineering Autonomous Colleges in Chen...  0.025288   Neutral
# 4     VIT vellore, SSN is currently the best autonom...  0.318450  Positive
# ...                                                 ...       ...       ...
# 1332  Admission process is explained below.. Admissi...  0.046626   Neutral
# 1333  Yes you can, also depends on the number of arr...  0.185286  Positive
# 1334  You can take a look at this, UNIVERSITY DEPART...  0.190633  Positive
# 1335  Primarily, it depends on your community. The r...  0.222180  Positive
# 1336   Depends on vacancy and respective college rules   0.421500  Positive
#
#          score  followers_n  engagement  sentiment_score
# 0     4.415200     0.032258           1         5.000000
# 1     3.393000     0.032258           1         4.393000
# 2     3.000000     0.064516           1              NaN
# 3     3.050575     0.096774           1         4.050575
# 4     3.636900     0.096774           1         4.636900
# ...        ...          ...         ...              ...
# 1332  3.093252     0.000000           0         3.093252
# 1333  3.370571     0.064516           1         4.370571
# 1334  3.381267     0.032258           1         4.381267
# 1335  3.444360     0.032258           1         4.444360
# 1336  3.843000     0.032258           1         4.843000
#
# [1337 rows x 17 columns]

# %%
df.rename(columns = {'score':'old_score'}, inplace = True) 
df.dropna()
# Out:
#       Unnamed: 0                             Topic  \
# 0              0  Anna-University-Tamil-Nadu-India
# 1              1  Anna-University-Tamil-Nadu-India
# 3              3  Anna-University-Tamil-Nadu-India
# 4              4  Anna-University-Tamil-Nadu-India
# 5              5  Anna-University-Tamil-Nadu-India
# ...          ...                               ...
# 1332        1332  Anna-University-Tamil-Nadu-India
# 1333        1333  Anna-University-Tamil-Nadu-India
# 1334        1334  Anna-University-Tamil-Nadu-India
# 1335        1335  Anna-University-Tamil-Nadu-India
# 1336        1336  Anna-University-Tamil-Nadu-India
#
#                                                question  Followers  Answers  \
# 0     Will I get CEG College in Chennai for the cuto...          1        2
# 1     Will I get CEG College in Chennai for the cuto...          1        2
# 3     Apart from Anna University what are the top 10...          3        3
# 4     Apart from Anna University what are the top 10...          3        3
# 5     Which type of exam will be conducted by Anna U...          1        1
# ...                                                 ...        ...      ...
# 1332  What is the procedure for an OCI holder to get...          0        1
# 1333  Can I be placed in campus if I study in the An...          2        1
# 1334  What is the cutoff mark to get into CEG Anna U...          1        5
# 1335  What is the cutoff mark to get into CEG Anna U...          1        5
# 1336  Can students transfer from an autonomous colle...          1        1
#
#      Ratio Engagement potential Last action Parsed time  \
# 0      1/2                   No    Followed  2020-08-02
# 1      1/2                   No    Followed  2020-08-02
# 3      3/3                   No    Followed  2020-08-02
# 4      3/3                   No    Followed  2020-08-02
# 5      1/1                   No    Followed  2020-07-30
# ...    ...                  ...         ...         ...
# 1332   0/1                   No   Requested  2018-02-18
# 1333   2/1                   No    Followed  2018-02-19
# 1334   1/5                   No   Requested  2018-02-18
# 1335   1/5                   No   Requested  2018-02-18
# 1336   1/1                   No    Followed  2018-02-17
#
#                                           Question link  \
# 0     https://www.quora.com/Will-I-get-CEG-College-i...
# 1     https://www.quora.com/Will-I-get-CEG-College-i...
# 3     https://www.quora.com/Apart-from-Anna-Universi...
# 4     https://www.quora.com/Apart-from-Anna-Universi...
# 5     https://www.quora.com/Which-type-of-exam-will-...
# ...                                                 ...
# 1332  https://www.quora.com/What-is-the-procedure-fo...
# 1333  https://www.quora.com/Can-I-be-placed-in-campu...
# 1334  https://www.quora.com/What-is-the-cutoff-mark-...
# 1335  https://www.quora.com/What-is-the-cutoff-mark-...
# 1336  https://www.quora.com/Can-students-transfer-fr...
#
#                                                 answers  compound Sentiment  \
# 0     Yes definitely u will get CEG, ACT, MIT, SSN. ...  0.707600  Positive
# 1     With this cutoff. U won't get any top branches...  0.196500  Positive
# 3     Top 10 Engineering Autonomous Colleges in Chen...  0.025288   Neutral
# 4     VIT vellore, SSN is currently the best autonom...  0.318450  Positive
# 5     As per UGC guidelines. Lower sem no exams, but... -0.148000  Negative
# ...                                                 ...       ...       ...
# 1332  Admission process is explained below.. Admissi...  0.046626   Neutral
# 1333  Yes you can, also depends on the number of arr...  0.185286  Positive
# 1334  You can take a look at this, UNIVERSITY DEPART...  0.190633  Positive
# 1335  Primarily, it depends on your community. The r...  0.222180  Positive
# 1336   Depends on vacancy and respective college rules   0.421500  Positive
#
#       old_score  followers_n  engagement  sentiment_score
# 0      4.415200     0.032258           1         5.000000
# 1      3.393000     0.032258           1         4.393000
# 3      3.050575     0.096774           1         4.050575
# 4      3.636900     0.096774           1         4.636900
# 5      2.704000     0.032258           1         1.704000
# ...         ...          ...         ...              ...
# 1332   3.093252     0.000000           0         3.093252
# 1333   3.370571     0.064516           1         4.370571
# 1334   3.381267     0.032258           1         4.381267
# 1335   3.444360     0.032258           1         4.444360
# 1336   3.843000     0.032258           1         4.843000
#
# [1147 rows x 17 columns]

# %%
df.to_csv('../../Datasets/Quora/WSA/AnnaQuoraWSA.csv')
