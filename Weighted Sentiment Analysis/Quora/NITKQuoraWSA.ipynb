# %%
import json
import csv
#import tweepy
import re
import nltk
from nltk.stem import WordNetLemmatizer
import pandas as pd
#import GetOldTweets3 as got
from nltk.corpus import stopwords
stopwords = set(stopwords.words('english'))
lemmatizer = WordNetLemmatizer()
import numpy as np
from nltk import tokenize
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
nltk.download("punkt")
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Kirthika\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
df=pd.read_csv('../../Datasets/Quora/Data/NITKQuora.csv')

#df = df.dropna()

# %%
df
# Out:
#      Unnamed: 0                                              Topic  \
# 0             0  National-Institute-of-Technology-Karnataka-Sur...
# 1             1  National-Institute-of-Technology-Karnataka-Sur...
# 2             2  National-Institute-of-Technology-Karnataka-Sur...
# 3             3  National-Institute-of-Technology-Karnataka-Sur...
# 4             4  National-Institute-of-Technology-Karnataka-Sur...
# ..          ...                                                ...
# 860         860  National-Institute-of-Technology-Karnataka-Sur...
# 861         861  National-Institute-of-Technology-Karnataka-Sur...
# 862         862  National-Institute-of-Technology-Karnataka-Sur...
# 863         863  National-Institute-of-Technology-Karnataka-Sur...
# 864         864  National-Institute-of-Technology-Karnataka-Sur...
#
#                                               question  Followers  Answers  \
# 0    Do M.Tech students of NITs Trichy/Surathkal/Wa...          1        3
# 1    Do M.Tech students of NITs Trichy/Surathkal/Wa...          1        3
# 2    Do M.Tech students of NITs Trichy/Surathkal/Wa...          1        3
# 3    I got a 97.63 percentile in the Mains. Which b...          0        1
# 4    I have been alloted IIT Bombay (RA) in Electro...          0        1
# ..                                                 ...        ...      ...
# 860  What do you think is better between IIIT Banga...          1        1
# 861  Which college should I choose for an M.Tech (C...          2        1
# 862  Are 220 marks in the JEE Mains enough to get i...         22        2
# 863  Are 220 marks in the JEE Mains enough to get i...         22        2
# 864  Which things should I do to complete an MTech ...         14        1
#
#     Ratio Engagement potential Last action Parsed time  \
# 0     1/3                   No   Requested  2020-08-03
# 1     1/3                   No   Requested  2020-08-03
# 2     1/3                   No   Requested  2020-08-03
# 3     0/1                   No   Requested  2020-08-01
# 4     0/1                   No   Requested  2020-08-01
# ..    ...                  ...         ...         ...
# 860   1/1                   No    Followed  2019-07-07
# 861   2/1                   No    Followed  2018-07-21
# 862  22/2                  Yes    Followed  2018-07-19
# 863  22/2                  Yes    Followed  2018-07-19
# 864  14/1                  Yes    Followed  2018-07-19
#
#                                          Question link  \
# 0    https://www.quora.com/Do-M-Tech-students-of-NI...
# 1    https://www.quora.com/Do-M-Tech-students-of-NI...
# 2    https://www.quora.com/Do-M-Tech-students-of-NI...
# 3    https://www.quora.com/I-got-a-97-63-percentile...
# 4    https://www.quora.com/I-have-been-alloted-IIT-...
# ..                                                 ...
# 860  https://www.quora.com/What-do-you-think-is-bet...
# 861  https://www.quora.com/Which-college-should-I-c...
# 862  https://www.quora.com/Are-220-marks-in-the-JEE...
# 863  https://www.quora.com/Are-220-marks-in-the-JEE...
# 864  https://www.quora.com/Which-things-should-I-do...
#
#                                                answers
# 0    firstly ragging is strictly prohibited in all ...
# 1    I am not graduate from this NITs but one of my...
# 2    I completed my M.Tech from NIT Trichy. I didn’...
# 3                         Civil metallurgy and mining
# 4                                          Vlsi nitk.
# ..                                                 ...
# 860  Firstly, the fact that you present so many opt...
# 861  Since all the above mentioned colleges in your...
# 862  Its more than enough to get mechanical in one ...
# 863  Yup very easily… With 220 marks u can easily g...
# 864  If you want to complete your MTech by research...
#
# [865 rows x 11 columns]

# %%
df=df.reset_index()

# %%
df=df.drop_duplicates()

# %%
df=df.drop(['index'],axis=1)

# %%
def vader_score(paragraph):
    analyzer = SentimentIntensityAnalyzer()
    paragraphSentiments = 0.0
    avg = -1
    sentence_list = tokenize.sent_tokenize(paragraph)
    size = len(sentence_list)
    #print(len((sentence_list))
    for sentence in sentence_list :
        vs = analyzer.polarity_scores(sentence)
        paragraphSentiments += vs["compound"]
    if( size == 0):
        print("zero")
    else:
        avg = (paragraphSentiments / size)
    return avg

# %%
df['compound'] = df['answers'].apply(lambda x: vader_score(x))
# Out:
# zero
# zero

# %%
i = df[df['compound'] == -1].index
df.drop(i)
# Out:
#      Unnamed: 0                                              Topic  \
# 0             0  National-Institute-of-Technology-Karnataka-Sur...
# 1             1  National-Institute-of-Technology-Karnataka-Sur...
# 2             2  National-Institute-of-Technology-Karnataka-Sur...
# 3             3  National-Institute-of-Technology-Karnataka-Sur...
# 4             4  National-Institute-of-Technology-Karnataka-Sur...
# ..          ...                                                ...
# 860         860  National-Institute-of-Technology-Karnataka-Sur...
# 861         861  National-Institute-of-Technology-Karnataka-Sur...
# 862         862  National-Institute-of-Technology-Karnataka-Sur...
# 863         863  National-Institute-of-Technology-Karnataka-Sur...
# 864         864  National-Institute-of-Technology-Karnataka-Sur...
#
#                                               question  Followers  Answers  \
# 0    Do M.Tech students of NITs Trichy/Surathkal/Wa...          1        3
# 1    Do M.Tech students of NITs Trichy/Surathkal/Wa...          1        3
# 2    Do M.Tech students of NITs Trichy/Surathkal/Wa...          1        3
# 3    I got a 97.63 percentile in the Mains. Which b...          0        1
# 4    I have been alloted IIT Bombay (RA) in Electro...          0        1
# ..                                                 ...        ...      ...
# 860  What do you think is better between IIIT Banga...          1        1
# 861  Which college should I choose for an M.Tech (C...          2        1
# 862  Are 220 marks in the JEE Mains enough to get i...         22        2
# 863  Are 220 marks in the JEE Mains enough to get i...         22        2
# 864  Which things should I do to complete an MTech ...         14        1
#
#     Ratio Engagement potential Last action Parsed time  \
# 0     1/3                   No   Requested  2020-08-03
# 1     1/3                   No   Requested  2020-08-03
# 2     1/3                   No   Requested  2020-08-03
# 3     0/1                   No   Requested  2020-08-01
# 4     0/1                   No   Requested  2020-08-01
# ..    ...                  ...         ...         ...
# 860   1/1                   No    Followed  2019-07-07
# 861   2/1                   No    Followed  2018-07-21
# 862  22/2                  Yes    Followed  2018-07-19
# 863  22/2                  Yes    Followed  2018-07-19
# 864  14/1                  Yes    Followed  2018-07-19
#
#                                          Question link  \
# 0    https://www.quora.com/Do-M-Tech-students-of-NI...
# 1    https://www.quora.com/Do-M-Tech-students-of-NI...
# 2    https://www.quora.com/Do-M-Tech-students-of-NI...
# 3    https://www.quora.com/I-got-a-97-63-percentile...
# 4    https://www.quora.com/I-have-been-alloted-IIT-...
# ..                                                 ...
# 860  https://www.quora.com/What-do-you-think-is-bet...
# 861  https://www.quora.com/Which-college-should-I-c...
# 862  https://www.quora.com/Are-220-marks-in-the-JEE...
# 863  https://www.quora.com/Are-220-marks-in-the-JEE...
# 864  https://www.quora.com/Which-things-should-I-do...
#
#                                                answers  compound
# 0    firstly ragging is strictly prohibited in all ... -0.098667
# 1    I am not graduate from this NITs but one of my...  0.192467
# 2    I completed my M.Tech from NIT Trichy. I didn’...  0.180675
# 3                         Civil metallurgy and mining   0.000000
# 4                                          Vlsi nitk.   0.000000
# ..                                                 ...       ...
# 860  Firstly, the fact that you present so many opt...  0.187667
# 861  Since all the above mentioned colleges in your...  0.173710
# 862  Its more than enough to get mechanical in one ...  0.344600
# 863  Yup very easily… With 220 marks u can easily g...  0.270950
# 864  If you want to complete your MTech by research...  0.242380
#
# [863 rows x 12 columns]

# %%
#classifying sentiments as positive,negative and neutral
def sentiment(compound):
    res = ""
    if(compound >= 0.05):
        res="Positive"
    elif(compound <= - 0.05):
        res="Negative"
    else:
        res="Neutral"
    return res

df['Sentiment'] = df['compound'].apply(lambda x: sentiment(x))

# %%
df
# Out:
#      Unnamed: 0                                              Topic  \
# 0             0  National-Institute-of-Technology-Karnataka-Sur...
# 1             1  National-Institute-of-Technology-Karnataka-Sur...
# 2             2  National-Institute-of-Technology-Karnataka-Sur...
# 3             3  National-Institute-of-Technology-Karnataka-Sur...
# 4             4  National-Institute-of-Technology-Karnataka-Sur...
# ..          ...                                                ...
# 860         860  National-Institute-of-Technology-Karnataka-Sur...
# 861         861  National-Institute-of-Technology-Karnataka-Sur...
# 862         862  National-Institute-of-Technology-Karnataka-Sur...
# 863         863  National-Institute-of-Technology-Karnataka-Sur...
# 864         864  National-Institute-of-Technology-Karnataka-Sur...
#
#                                               question  Followers  Answers  \
# 0    Do M.Tech students of NITs Trichy/Surathkal/Wa...          1        3
# 1    Do M.Tech students of NITs Trichy/Surathkal/Wa...          1        3
# 2    Do M.Tech students of NITs Trichy/Surathkal/Wa...          1        3
# 3    I got a 97.63 percentile in the Mains. Which b...          0        1
# 4    I have been alloted IIT Bombay (RA) in Electro...          0        1
# ..                                                 ...        ...      ...
# 860  What do you think is better between IIIT Banga...          1        1
# 861  Which college should I choose for an M.Tech (C...          2        1
# 862  Are 220 marks in the JEE Mains enough to get i...         22        2
# 863  Are 220 marks in the JEE Mains enough to get i...         22        2
# 864  Which things should I do to complete an MTech ...         14        1
#
#     Ratio Engagement potential Last action Parsed time  \
# 0     1/3                   No   Requested  2020-08-03
# 1     1/3                   No   Requested  2020-08-03
# 2     1/3                   No   Requested  2020-08-03
# 3     0/1                   No   Requested  2020-08-01
# 4     0/1                   No   Requested  2020-08-01
# ..    ...                  ...         ...         ...
# 860   1/1                   No    Followed  2019-07-07
# 861   2/1                   No    Followed  2018-07-21
# 862  22/2                  Yes    Followed  2018-07-19
# 863  22/2                  Yes    Followed  2018-07-19
# 864  14/1                  Yes    Followed  2018-07-19
#
#                                          Question link  \
# 0    https://www.quora.com/Do-M-Tech-students-of-NI...
# 1    https://www.quora.com/Do-M-Tech-students-of-NI...
# 2    https://www.quora.com/Do-M-Tech-students-of-NI...
# 3    https://www.quora.com/I-got-a-97-63-percentile...
# 4    https://www.quora.com/I-have-been-alloted-IIT-...
# ..                                                 ...
# 860  https://www.quora.com/What-do-you-think-is-bet...
# 861  https://www.quora.com/Which-college-should-I-c...
# 862  https://www.quora.com/Are-220-marks-in-the-JEE...
# 863  https://www.quora.com/Are-220-marks-in-the-JEE...
# 864  https://www.quora.com/Which-things-should-I-do...
#
#                                                answers  compound Sentiment
# 0    firstly ragging is strictly prohibited in all ... -0.098667  Negative
# 1    I am not graduate from this NITs but one of my...  0.192467  Positive
# 2    I completed my M.Tech from NIT Trichy. I didn’...  0.180675  Positive
# 3                         Civil metallurgy and mining   0.000000   Neutral
# 4                                          Vlsi nitk.   0.000000   Neutral
# ..                                                 ...       ...       ...
# 860  Firstly, the fact that you present so many opt...  0.187667  Positive
# 861  Since all the above mentioned colleges in your...  0.173710  Positive
# 862  Its more than enough to get mechanical in one ...  0.344600  Positive
# 863  Yup very easily… With 220 marks u can easily g...  0.270950  Positive
# 864  If you want to complete your MTech by research...  0.242380  Positive
#
# [865 rows x 13 columns]

# %%
def convert(score):
    OldRange = 2  
    NewRange = 4  
    NewValue = (((score + 1) * NewRange) / OldRange) + 1
    return NewValue
df['score'] = df['compound'].apply(lambda x: convert(x))
df
def assignpred(n):
    if n>1 and n<3:
        return max((n-1),1)
    if n>3 and n<5:
        return min((n+1),5)

# %%
def normalize(feature):
    max_value = df[feature].max()
    min_value = df[feature].min()
    result = (df[feature] - min_value) / (max_value - min_value)
    return result

# %%
df['followers_n']=normalize('Followers')

# %%
df
# Out:
#      Unnamed: 0                                              Topic  \
# 0             0  National-Institute-of-Technology-Karnataka-Sur...
# 1             1  National-Institute-of-Technology-Karnataka-Sur...
# 2             2  National-Institute-of-Technology-Karnataka-Sur...
# 3             3  National-Institute-of-Technology-Karnataka-Sur...
# 4             4  National-Institute-of-Technology-Karnataka-Sur...
# ..          ...                                                ...
# 860         860  National-Institute-of-Technology-Karnataka-Sur...
# 861         861  National-Institute-of-Technology-Karnataka-Sur...
# 862         862  National-Institute-of-Technology-Karnataka-Sur...
# 863         863  National-Institute-of-Technology-Karnataka-Sur...
# 864         864  National-Institute-of-Technology-Karnataka-Sur...
#
#                                               question  Followers  Answers  \
# 0    Do M.Tech students of NITs Trichy/Surathkal/Wa...          1        3
# 1    Do M.Tech students of NITs Trichy/Surathkal/Wa...          1        3
# 2    Do M.Tech students of NITs Trichy/Surathkal/Wa...          1        3
# 3    I got a 97.63 percentile in the Mains. Which b...          0        1
# 4    I have been alloted IIT Bombay (RA) in Electro...          0        1
# ..                                                 ...        ...      ...
# 860  What do you think is better between IIIT Banga...          1        1
# 861  Which college should I choose for an M.Tech (C...          2        1
# 862  Are 220 marks in the JEE Mains enough to get i...         22        2
# 863  Are 220 marks in the JEE Mains enough to get i...         22        2
# 864  Which things should I do to complete an MTech ...         14        1
#
#     Ratio Engagement potential Last action Parsed time  \
# 0     1/3                   No   Requested  2020-08-03
# 1     1/3                   No   Requested  2020-08-03
# 2     1/3                   No   Requested  2020-08-03
# 3     0/1                   No   Requested  2020-08-01
# 4     0/1                   No   Requested  2020-08-01
# ..    ...                  ...         ...         ...
# 860   1/1                   No    Followed  2019-07-07
# 861   2/1                   No    Followed  2018-07-21
# 862  22/2                  Yes    Followed  2018-07-19
# 863  22/2                  Yes    Followed  2018-07-19
# 864  14/1                  Yes    Followed  2018-07-19
#
#                                          Question link  \
# 0    https://www.quora.com/Do-M-Tech-students-of-NI...
# 1    https://www.quora.com/Do-M-Tech-students-of-NI...
# 2    https://www.quora.com/Do-M-Tech-students-of-NI...
# 3    https://www.quora.com/I-got-a-97-63-percentile...
# 4    https://www.quora.com/I-have-been-alloted-IIT-...
# ..                                                 ...
# 860  https://www.quora.com/What-do-you-think-is-bet...
# 861  https://www.quora.com/Which-college-should-I-c...
# 862  https://www.quora.com/Are-220-marks-in-the-JEE...
# 863  https://www.quora.com/Are-220-marks-in-the-JEE...
# 864  https://www.quora.com/Which-things-should-I-do...
#
#                                                answers  compound Sentiment  \
# 0    firstly ragging is strictly prohibited in all ... -0.098667  Negative
# 1    I am not graduate from this NITs but one of my...  0.192467  Positive
# 2    I completed my M.Tech from NIT Trichy. I didn’...  0.180675  Positive
# 3                         Civil metallurgy and mining   0.000000   Neutral
# 4                                          Vlsi nitk.   0.000000   Neutral
# ..                                                 ...       ...       ...
# 860  Firstly, the fact that you present so many opt...  0.187667  Positive
# 861  Since all the above mentioned colleges in your...  0.173710  Positive
# 862  Its more than enough to get mechanical in one ...  0.344600  Positive
# 863  Yup very easily… With 220 marks u can easily g...  0.270950  Positive
# 864  If you want to complete your MTech by research...  0.242380  Positive
#
#         score  followers_n
# 0    2.802667     0.016129
# 1    3.384933     0.016129
# 2    3.361350     0.016129
# 3    3.000000     0.000000
# 4    3.000000     0.000000
# ..        ...          ...
# 860  3.375333     0.016129
# 861  3.347420     0.032258
# 862  3.689200     0.354839
# 863  3.541900     0.354839
# 864  3.484760     0.225806
#
# [865 rows x 15 columns]

# %%
engagement_median = df['followers_n'].median()
df["engagement"] = df['followers_n'].apply(lambda x: 1 if x >= engagement_median else 0)

# %%
df['sentiment_score']=df['score']
df_eng1=df[df.engagement==1]
#if engagement score is greater than the median, increase the positive and negative sentiment
df_eng1['sentiment_score']=df_eng1['score'].apply(lambda x: assignpred(x))
df[df.engagement==1]=df_eng1
df
# Out:
# C:\Users\Kirthika\anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
#      Unnamed: 0                                              Topic  \
# 0             0  National-Institute-of-Technology-Karnataka-Sur...
# 1             1  National-Institute-of-Technology-Karnataka-Sur...
# 2             2  National-Institute-of-Technology-Karnataka-Sur...
# 3             3  National-Institute-of-Technology-Karnataka-Sur...
# 4             4  National-Institute-of-Technology-Karnataka-Sur...
# ..          ...                                                ...
# 860         860  National-Institute-of-Technology-Karnataka-Sur...
# 861         861  National-Institute-of-Technology-Karnataka-Sur...
# 862         862  National-Institute-of-Technology-Karnataka-Sur...
# 863         863  National-Institute-of-Technology-Karnataka-Sur...
# 864         864  National-Institute-of-Technology-Karnataka-Sur...
#
#                                               question  Followers  Answers  \
# 0    Do M.Tech students of NITs Trichy/Surathkal/Wa...          1        3
# 1    Do M.Tech students of NITs Trichy/Surathkal/Wa...          1        3
# 2    Do M.Tech students of NITs Trichy/Surathkal/Wa...          1        3
# 3    I got a 97.63 percentile in the Mains. Which b...          0        1
# 4    I have been alloted IIT Bombay (RA) in Electro...          0        1
# ..                                                 ...        ...      ...
# 860  What do you think is better between IIIT Banga...          1        1
# 861  Which college should I choose for an M.Tech (C...          2        1
# 862  Are 220 marks in the JEE Mains enough to get i...         22        2
# 863  Are 220 marks in the JEE Mains enough to get i...         22        2
# 864  Which things should I do to complete an MTech ...         14        1
#
#     Ratio Engagement potential Last action Parsed time  \
# 0     1/3                   No   Requested  2020-08-03
# 1     1/3                   No   Requested  2020-08-03
# 2     1/3                   No   Requested  2020-08-03
# 3     0/1                   No   Requested  2020-08-01
# 4     0/1                   No   Requested  2020-08-01
# ..    ...                  ...         ...         ...
# 860   1/1                   No    Followed  2019-07-07
# 861   2/1                   No    Followed  2018-07-21
# 862  22/2                  Yes    Followed  2018-07-19
# 863  22/2                  Yes    Followed  2018-07-19
# 864  14/1                  Yes    Followed  2018-07-19
#
#                                          Question link  \
# 0    https://www.quora.com/Do-M-Tech-students-of-NI...
# 1    https://www.quora.com/Do-M-Tech-students-of-NI...
# 2    https://www.quora.com/Do-M-Tech-students-of-NI...
# 3    https://www.quora.com/I-got-a-97-63-percentile...
# 4    https://www.quora.com/I-have-been-alloted-IIT-...
# ..                                                 ...
# 860  https://www.quora.com/What-do-you-think-is-bet...
# 861  https://www.quora.com/Which-college-should-I-c...
# 862  https://www.quora.com/Are-220-marks-in-the-JEE...
# 863  https://www.quora.com/Are-220-marks-in-the-JEE...
# 864  https://www.quora.com/Which-things-should-I-do...
#
#                                                answers  compound Sentiment  \
# 0    firstly ragging is strictly prohibited in all ... -0.098667  Negative
# 1    I am not graduate from this NITs but one of my...  0.192467  Positive
# 2    I completed my M.Tech from NIT Trichy. I didn’...  0.180675  Positive
# 3                         Civil metallurgy and mining   0.000000   Neutral
# 4                                          Vlsi nitk.   0.000000   Neutral
# ..                                                 ...       ...       ...
# 860  Firstly, the fact that you present so many opt...  0.187667  Positive
# 861  Since all the above mentioned colleges in your...  0.173710  Positive
# 862  Its more than enough to get mechanical in one ...  0.344600  Positive
# 863  Yup very easily… With 220 marks u can easily g...  0.270950  Positive
# 864  If you want to complete your MTech by research...  0.242380  Positive
#
#         score  followers_n  engagement  sentiment_score
# 0    2.802667     0.016129           0         2.802667
# 1    3.384933     0.016129           0         3.384933
# 2    3.361350     0.016129           0         3.361350
# 3    3.000000     0.000000           0         3.000000
# 4    3.000000     0.000000           0         3.000000
# ..        ...          ...         ...              ...
# 860  3.375333     0.016129           0         3.375333
# 861  3.347420     0.032258           1         4.347420
# 862  3.689200     0.354839           1         4.689200
# 863  3.541900     0.354839           1         4.541900
# 864  3.484760     0.225806           1         4.484760
#
# [865 rows x 17 columns]

# %%
df.rename(columns = {'score':'old_score'}, inplace = True) 
df.dropna()
# Out:
#      Unnamed: 0                                              Topic  \
# 0             0  National-Institute-of-Technology-Karnataka-Sur...
# 1             1  National-Institute-of-Technology-Karnataka-Sur...
# 2             2  National-Institute-of-Technology-Karnataka-Sur...
# 3             3  National-Institute-of-Technology-Karnataka-Sur...
# 4             4  National-Institute-of-Technology-Karnataka-Sur...
# ..          ...                                                ...
# 860         860  National-Institute-of-Technology-Karnataka-Sur...
# 861         861  National-Institute-of-Technology-Karnataka-Sur...
# 862         862  National-Institute-of-Technology-Karnataka-Sur...
# 863         863  National-Institute-of-Technology-Karnataka-Sur...
# 864         864  National-Institute-of-Technology-Karnataka-Sur...
#
#                                               question  Followers  Answers  \
# 0    Do M.Tech students of NITs Trichy/Surathkal/Wa...          1        3
# 1    Do M.Tech students of NITs Trichy/Surathkal/Wa...          1        3
# 2    Do M.Tech students of NITs Trichy/Surathkal/Wa...          1        3
# 3    I got a 97.63 percentile in the Mains. Which b...          0        1
# 4    I have been alloted IIT Bombay (RA) in Electro...          0        1
# ..                                                 ...        ...      ...
# 860  What do you think is better between IIIT Banga...          1        1
# 861  Which college should I choose for an M.Tech (C...          2        1
# 862  Are 220 marks in the JEE Mains enough to get i...         22        2
# 863  Are 220 marks in the JEE Mains enough to get i...         22        2
# 864  Which things should I do to complete an MTech ...         14        1
#
#     Ratio Engagement potential Last action Parsed time  \
# 0     1/3                   No   Requested  2020-08-03
# 1     1/3                   No   Requested  2020-08-03
# 2     1/3                   No   Requested  2020-08-03
# 3     0/1                   No   Requested  2020-08-01
# 4     0/1                   No   Requested  2020-08-01
# ..    ...                  ...         ...         ...
# 860   1/1                   No    Followed  2019-07-07
# 861   2/1                   No    Followed  2018-07-21
# 862  22/2                  Yes    Followed  2018-07-19
# 863  22/2                  Yes    Followed  2018-07-19
# 864  14/1                  Yes    Followed  2018-07-19
#
#                                          Question link  \
# 0    https://www.quora.com/Do-M-Tech-students-of-NI...
# 1    https://www.quora.com/Do-M-Tech-students-of-NI...
# 2    https://www.quora.com/Do-M-Tech-students-of-NI...
# 3    https://www.quora.com/I-got-a-97-63-percentile...
# 4    https://www.quora.com/I-have-been-alloted-IIT-...
# ..                                                 ...
# 860  https://www.quora.com/What-do-you-think-is-bet...
# 861  https://www.quora.com/Which-college-should-I-c...
# 862  https://www.quora.com/Are-220-marks-in-the-JEE...
# 863  https://www.quora.com/Are-220-marks-in-the-JEE...
# 864  https://www.quora.com/Which-things-should-I-do...
#
#                                                answers  compound Sentiment  \
# 0    firstly ragging is strictly prohibited in all ... -0.098667  Negative
# 1    I am not graduate from this NITs but one of my...  0.192467  Positive
# 2    I completed my M.Tech from NIT Trichy. I didn’...  0.180675  Positive
# 3                         Civil metallurgy and mining   0.000000   Neutral
# 4                                          Vlsi nitk.   0.000000   Neutral
# ..                                                 ...       ...       ...
# 860  Firstly, the fact that you present so many opt...  0.187667  Positive
# 861  Since all the above mentioned colleges in your...  0.173710  Positive
# 862  Its more than enough to get mechanical in one ...  0.344600  Positive
# 863  Yup very easily… With 220 marks u can easily g...  0.270950  Positive
# 864  If you want to complete your MTech by research...  0.242380  Positive
#
#      old_score  followers_n  engagement  sentiment_score
# 0     2.802667     0.016129           0         2.802667
# 1     3.384933     0.016129           0         3.384933
# 2     3.361350     0.016129           0         3.361350
# 3     3.000000     0.000000           0         3.000000
# 4     3.000000     0.000000           0         3.000000
# ..         ...          ...         ...              ...
# 860   3.375333     0.016129           0         3.375333
# 861   3.347420     0.032258           1         4.347420
# 862   3.689200     0.354839           1         4.689200
# 863   3.541900     0.354839           1         4.541900
# 864   3.484760     0.225806           1         4.484760
#
# [788 rows x 17 columns]

# %%
df.to_csv('../../Datasets/Quora/WSA/NITKQuoraWSA.csv')
