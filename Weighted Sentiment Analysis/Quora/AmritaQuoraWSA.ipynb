# %%
import json
import csv
#import tweepy
import re
import nltk
from nltk.stem import WordNetLemmatizer
import pandas as pd
#import GetOldTweets3 as got
from nltk.corpus import stopwords
stopwords = set(stopwords.words('english'))
lemmatizer = WordNetLemmatizer()
import numpy as np
from nltk import tokenize
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
nltk.download("punkt")
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Kirthika\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
df=pd.read_csv('../../Datasets/Quora/Data/AmritaQuora.csv')

#df = df.dropna()

# %%
df
# Out:
#     Unnamed: 0                                      Topic  \
# 0            0  Amrita-School-of-Engineering-Amritapuri-1
# 1            1  Amrita-School-of-Engineering-Amritapuri-1
# 2            2        Amrita-University-Amritapuri-Campus
# 3            3        Amrita-University-Amritapuri-Campus
# 4            4  Amrita-School-of-Engineering-Amritapuri-1
# ..         ...                                        ...
# 81          81        Amrita-University-Amritapuri-Campus
# 82          82        Amrita-University-Amritapuri-Campus
# 83          83        Amrita-University-Amritapuri-Campus
# 84          84        Amrita-University-Amritapuri-Campus
# 85          85        Amrita-University-Amritapuri-Campus
#
#                                              question  Followers  Answers  \
# 0   Which is the best of Amrita Amritapuri or Coim...          1        1
# 1   Which is the best of Amrita Amritapuri or Coim...          1        1
# 2   Which is the best of Amrita Amritapuri or Coim...          1        1
# 3   Which is the best of Amrita Amritapuri or Coim...          1        1
# 4   Will the Amrita entrance exam be postponed again?          1        1
# ..                                                ...        ...      ...
# 81  What would be a better choice for somebody who...          1        3
# 82      How is life at Amrita University, Amritapuri?          5        5
# 83      How is life at Amrita University, Amritapuri?          5        5
# 84   Are mobiles allowed in Amrita Amritapuri campus?          6        3
# 85   Are mobiles allowed in Amrita Amritapuri campus?          6        3
#
#    Ratio Engagement potential Last action Parsed time  \
# 0    1/1                   No    Followed  2020-07-19
# 1    1/1                   No    Followed  2020-07-19
# 2    1/1                   No    Followed  2020-07-19
# 3    1/1                   No    Followed  2020-07-19
# 4    1/1                   No    Followed  2020-06-17
# ..   ...                  ...         ...         ...
# 81   1/3                   No    Followed  2018-04-20
# 82   5/5                   No    Followed  2019-07-29
# 83   5/5                   No    Followed  2019-07-29
# 84   6/3                   No    Followed  2017-06-27
# 85   6/3                   No    Followed  2017-06-27
#
#                                         Question link  \
# 0   https://www.quora.com/Which-is-the-best-of-Amr...
# 1   https://www.quora.com/Which-is-the-best-of-Amr...
# 2   https://www.quora.com/Which-is-the-best-of-Amr...
# 3   https://www.quora.com/Which-is-the-best-of-Amr...
# 4   https://www.quora.com/Will-the-Amrita-entrance...
# ..                                                ...
# 81  https://www.quora.com/What-would-be-a-better-c...
# 82  https://www.quora.com/How-is-life-at-Amrita-Un...
# 83  https://www.quora.com/How-is-life-at-Amrita-Un...
# 84  https://www.quora.com/Are-mobiles-allowed-in-A...
# 85  https://www.quora.com/Are-mobiles-allowed-in-A...
#
#                                               answers
# 0   Coimbatore is more of a good option but then d...
# 1   Coimbatore is more of a good option but then d...
# 2   Coimbatore is more of a good option but then d...
# 3   Coimbatore is more of a good option but then d...
# 4   Hello there, Amrita entrance has been schedule...
# ..                                                ...
# 81  I would recommend pursuing CSE at the Amritapu...
# 82  Going anonymous for obvious reasons. Well, lif...
# 83  Life at Amrita University is a mix of both goo...
# 84  I'm currently studying as a first year btech s...
# 85  Yes, but after second year. In first year mobi...
#
# [86 rows x 11 columns]

# %%
df=df.reset_index()

# %%
df=df.drop_duplicates()

# %%
df=df.drop(['index'],axis=1)

# %%
def vader_score(paragraph):
    analyzer = SentimentIntensityAnalyzer()
    paragraphSentiments = 0.0
    avg = -1
    sentence_list = tokenize.sent_tokenize(paragraph)
    size = len(sentence_list)
    #print(len((sentence_list))
    for sentence in sentence_list :
        vs = analyzer.polarity_scores(sentence)
        paragraphSentiments += vs["compound"]
    if( size == 0):
        print("zero")
    else:
        avg = (paragraphSentiments / size)
    return avg

# %%
df['compound'] = df['answers'].apply(lambda x: vader_score(x))

# %%
i = df[df['compound'] == -1].index
df.drop(i)
# Out:
#     Unnamed: 0                                      Topic  \
# 0            0  Amrita-School-of-Engineering-Amritapuri-1
# 1            1  Amrita-School-of-Engineering-Amritapuri-1
# 2            2        Amrita-University-Amritapuri-Campus
# 3            3        Amrita-University-Amritapuri-Campus
# 4            4  Amrita-School-of-Engineering-Amritapuri-1
# ..         ...                                        ...
# 81          81        Amrita-University-Amritapuri-Campus
# 82          82        Amrita-University-Amritapuri-Campus
# 83          83        Amrita-University-Amritapuri-Campus
# 84          84        Amrita-University-Amritapuri-Campus
# 85          85        Amrita-University-Amritapuri-Campus
#
#                                              question  Followers  Answers  \
# 0   Which is the best of Amrita Amritapuri or Coim...          1        1
# 1   Which is the best of Amrita Amritapuri or Coim...          1        1
# 2   Which is the best of Amrita Amritapuri or Coim...          1        1
# 3   Which is the best of Amrita Amritapuri or Coim...          1        1
# 4   Will the Amrita entrance exam be postponed again?          1        1
# ..                                                ...        ...      ...
# 81  What would be a better choice for somebody who...          1        3
# 82      How is life at Amrita University, Amritapuri?          5        5
# 83      How is life at Amrita University, Amritapuri?          5        5
# 84   Are mobiles allowed in Amrita Amritapuri campus?          6        3
# 85   Are mobiles allowed in Amrita Amritapuri campus?          6        3
#
#    Ratio Engagement potential Last action Parsed time  \
# 0    1/1                   No    Followed  2020-07-19
# 1    1/1                   No    Followed  2020-07-19
# 2    1/1                   No    Followed  2020-07-19
# 3    1/1                   No    Followed  2020-07-19
# 4    1/1                   No    Followed  2020-06-17
# ..   ...                  ...         ...         ...
# 81   1/3                   No    Followed  2018-04-20
# 82   5/5                   No    Followed  2019-07-29
# 83   5/5                   No    Followed  2019-07-29
# 84   6/3                   No    Followed  2017-06-27
# 85   6/3                   No    Followed  2017-06-27
#
#                                         Question link  \
# 0   https://www.quora.com/Which-is-the-best-of-Amr...
# 1   https://www.quora.com/Which-is-the-best-of-Amr...
# 2   https://www.quora.com/Which-is-the-best-of-Amr...
# 3   https://www.quora.com/Which-is-the-best-of-Amr...
# 4   https://www.quora.com/Will-the-Amrita-entrance...
# ..                                                ...
# 81  https://www.quora.com/What-would-be-a-better-c...
# 82  https://www.quora.com/How-is-life-at-Amrita-Un...
# 83  https://www.quora.com/How-is-life-at-Amrita-Un...
# 84  https://www.quora.com/Are-mobiles-allowed-in-A...
# 85  https://www.quora.com/Are-mobiles-allowed-in-A...
#
#                                               answers  compound
# 0   Coimbatore is more of a good option but then d...  0.367800
# 1   Coimbatore is more of a good option but then d...  0.367800
# 2   Coimbatore is more of a good option but then d...  0.367800
# 3   Coimbatore is more of a good option but then d...  0.367800
# 4   Hello there, Amrita entrance has been schedule... -0.074000
# ..                                                ...       ...
# 81  I would recommend pursuing CSE at the Amritapu...  0.549067
# 82  Going anonymous for obvious reasons. Well, lif...  0.043238
# 83  Life at Amrita University is a mix of both goo...  0.100895
# 84  I'm currently studying as a first year btech s...  0.320700
# 85  Yes, but after second year. In first year mobi...  0.042880
#
# [86 rows x 12 columns]

# %%
#classifying sentiments as positive,negative and neutral
def sentiment(compound):
    res = ""
    if(compound >= 0.05):
        res="Positive"
    elif(compound <= - 0.05):
        res="Negative"
    else:
        res="Neutral"
    return res

df['Sentiment'] = df['compound'].apply(lambda x: sentiment(x))

# %%
df
# Out:
#     Unnamed: 0                                      Topic  \
# 0            0  Amrita-School-of-Engineering-Amritapuri-1
# 1            1  Amrita-School-of-Engineering-Amritapuri-1
# 2            2        Amrita-University-Amritapuri-Campus
# 3            3        Amrita-University-Amritapuri-Campus
# 4            4  Amrita-School-of-Engineering-Amritapuri-1
# ..         ...                                        ...
# 81          81        Amrita-University-Amritapuri-Campus
# 82          82        Amrita-University-Amritapuri-Campus
# 83          83        Amrita-University-Amritapuri-Campus
# 84          84        Amrita-University-Amritapuri-Campus
# 85          85        Amrita-University-Amritapuri-Campus
#
#                                              question  Followers  Answers  \
# 0   Which is the best of Amrita Amritapuri or Coim...          1        1
# 1   Which is the best of Amrita Amritapuri or Coim...          1        1
# 2   Which is the best of Amrita Amritapuri or Coim...          1        1
# 3   Which is the best of Amrita Amritapuri or Coim...          1        1
# 4   Will the Amrita entrance exam be postponed again?          1        1
# ..                                                ...        ...      ...
# 81  What would be a better choice for somebody who...          1        3
# 82      How is life at Amrita University, Amritapuri?          5        5
# 83      How is life at Amrita University, Amritapuri?          5        5
# 84   Are mobiles allowed in Amrita Amritapuri campus?          6        3
# 85   Are mobiles allowed in Amrita Amritapuri campus?          6        3
#
#    Ratio Engagement potential Last action Parsed time  \
# 0    1/1                   No    Followed  2020-07-19
# 1    1/1                   No    Followed  2020-07-19
# 2    1/1                   No    Followed  2020-07-19
# 3    1/1                   No    Followed  2020-07-19
# 4    1/1                   No    Followed  2020-06-17
# ..   ...                  ...         ...         ...
# 81   1/3                   No    Followed  2018-04-20
# 82   5/5                   No    Followed  2019-07-29
# 83   5/5                   No    Followed  2019-07-29
# 84   6/3                   No    Followed  2017-06-27
# 85   6/3                   No    Followed  2017-06-27
#
#                                         Question link  \
# 0   https://www.quora.com/Which-is-the-best-of-Amr...
# 1   https://www.quora.com/Which-is-the-best-of-Amr...
# 2   https://www.quora.com/Which-is-the-best-of-Amr...
# 3   https://www.quora.com/Which-is-the-best-of-Amr...
# 4   https://www.quora.com/Will-the-Amrita-entrance...
# ..                                                ...
# 81  https://www.quora.com/What-would-be-a-better-c...
# 82  https://www.quora.com/How-is-life-at-Amrita-Un...
# 83  https://www.quora.com/How-is-life-at-Amrita-Un...
# 84  https://www.quora.com/Are-mobiles-allowed-in-A...
# 85  https://www.quora.com/Are-mobiles-allowed-in-A...
#
#                                               answers  compound Sentiment
# 0   Coimbatore is more of a good option but then d...  0.367800  Positive
# 1   Coimbatore is more of a good option but then d...  0.367800  Positive
# 2   Coimbatore is more of a good option but then d...  0.367800  Positive
# 3   Coimbatore is more of a good option but then d...  0.367800  Positive
# 4   Hello there, Amrita entrance has been schedule... -0.074000  Negative
# ..                                                ...       ...       ...
# 81  I would recommend pursuing CSE at the Amritapu...  0.549067  Positive
# 82  Going anonymous for obvious reasons. Well, lif...  0.043238   Neutral
# 83  Life at Amrita University is a mix of both goo...  0.100895  Positive
# 84  I'm currently studying as a first year btech s...  0.320700  Positive
# 85  Yes, but after second year. In first year mobi...  0.042880   Neutral
#
# [86 rows x 13 columns]

# %%
def convert(score):
    OldRange = 2  
    NewRange = 4  
    NewValue = (((score + 1) * NewRange) / OldRange) + 1
    return NewValue
df['score'] = df['compound'].apply(lambda x: convert(x))
df
# Out:
#     Unnamed: 0                                      Topic  \
# 0            0  Amrita-School-of-Engineering-Amritapuri-1
# 1            1  Amrita-School-of-Engineering-Amritapuri-1
# 2            2        Amrita-University-Amritapuri-Campus
# 3            3        Amrita-University-Amritapuri-Campus
# 4            4  Amrita-School-of-Engineering-Amritapuri-1
# ..         ...                                        ...
# 81          81        Amrita-University-Amritapuri-Campus
# 82          82        Amrita-University-Amritapuri-Campus
# 83          83        Amrita-University-Amritapuri-Campus
# 84          84        Amrita-University-Amritapuri-Campus
# 85          85        Amrita-University-Amritapuri-Campus
#
#                                              question  Followers  Answers  \
# 0   Which is the best of Amrita Amritapuri or Coim...          1        1
# 1   Which is the best of Amrita Amritapuri or Coim...          1        1
# 2   Which is the best of Amrita Amritapuri or Coim...          1        1
# 3   Which is the best of Amrita Amritapuri or Coim...          1        1
# 4   Will the Amrita entrance exam be postponed again?          1        1
# ..                                                ...        ...      ...
# 81  What would be a better choice for somebody who...          1        3
# 82      How is life at Amrita University, Amritapuri?          5        5
# 83      How is life at Amrita University, Amritapuri?          5        5
# 84   Are mobiles allowed in Amrita Amritapuri campus?          6        3
# 85   Are mobiles allowed in Amrita Amritapuri campus?          6        3
#
#    Ratio Engagement potential Last action Parsed time  \
# 0    1/1                   No    Followed  2020-07-19
# 1    1/1                   No    Followed  2020-07-19
# 2    1/1                   No    Followed  2020-07-19
# 3    1/1                   No    Followed  2020-07-19
# 4    1/1                   No    Followed  2020-06-17
# ..   ...                  ...         ...         ...
# 81   1/3                   No    Followed  2018-04-20
# 82   5/5                   No    Followed  2019-07-29
# 83   5/5                   No    Followed  2019-07-29
# 84   6/3                   No    Followed  2017-06-27
# 85   6/3                   No    Followed  2017-06-27
#
#                                         Question link  \
# 0   https://www.quora.com/Which-is-the-best-of-Amr...
# 1   https://www.quora.com/Which-is-the-best-of-Amr...
# 2   https://www.quora.com/Which-is-the-best-of-Amr...
# 3   https://www.quora.com/Which-is-the-best-of-Amr...
# 4   https://www.quora.com/Will-the-Amrita-entrance...
# ..                                                ...
# 81  https://www.quora.com/What-would-be-a-better-c...
# 82  https://www.quora.com/How-is-life-at-Amrita-Un...
# 83  https://www.quora.com/How-is-life-at-Amrita-Un...
# 84  https://www.quora.com/Are-mobiles-allowed-in-A...
# 85  https://www.quora.com/Are-mobiles-allowed-in-A...
#
#                                               answers  compound Sentiment  \
# 0   Coimbatore is more of a good option but then d...  0.367800  Positive
# 1   Coimbatore is more of a good option but then d...  0.367800  Positive
# 2   Coimbatore is more of a good option but then d...  0.367800  Positive
# 3   Coimbatore is more of a good option but then d...  0.367800  Positive
# 4   Hello there, Amrita entrance has been schedule... -0.074000  Negative
# ..                                                ...       ...       ...
# 81  I would recommend pursuing CSE at the Amritapu...  0.549067  Positive
# 82  Going anonymous for obvious reasons. Well, lif...  0.043238   Neutral
# 83  Life at Amrita University is a mix of both goo...  0.100895  Positive
# 84  I'm currently studying as a first year btech s...  0.320700  Positive
# 85  Yes, but after second year. In first year mobi...  0.042880   Neutral
#
#        score
# 0   3.735600
# 1   3.735600
# 2   3.735600
# 3   3.735600
# 4   2.852000
# ..       ...
# 81  4.098133
# 82  3.086477
# 83  3.201791
# 84  3.641400
# 85  3.085760
#
# [86 rows x 14 columns]

# %%
def normalize(feature):
    max_value = df[feature].max()
    min_value = df[feature].min()
    result = (df[feature] - min_value) / (max_value - min_value)
    return result

# %%
df['followers_n']=normalize('Followers')

# %%
df
# Out:
#     Unnamed: 0                                      Topic  \
# 0            0  Amrita-School-of-Engineering-Amritapuri-1
# 1            1  Amrita-School-of-Engineering-Amritapuri-1
# 2            2        Amrita-University-Amritapuri-Campus
# 3            3        Amrita-University-Amritapuri-Campus
# 4            4  Amrita-School-of-Engineering-Amritapuri-1
# ..         ...                                        ...
# 81          81        Amrita-University-Amritapuri-Campus
# 82          82        Amrita-University-Amritapuri-Campus
# 83          83        Amrita-University-Amritapuri-Campus
# 84          84        Amrita-University-Amritapuri-Campus
# 85          85        Amrita-University-Amritapuri-Campus
#
#                                              question  Followers  Answers  \
# 0   Which is the best of Amrita Amritapuri or Coim...          1        1
# 1   Which is the best of Amrita Amritapuri or Coim...          1        1
# 2   Which is the best of Amrita Amritapuri or Coim...          1        1
# 3   Which is the best of Amrita Amritapuri or Coim...          1        1
# 4   Will the Amrita entrance exam be postponed again?          1        1
# ..                                                ...        ...      ...
# 81  What would be a better choice for somebody who...          1        3
# 82      How is life at Amrita University, Amritapuri?          5        5
# 83      How is life at Amrita University, Amritapuri?          5        5
# 84   Are mobiles allowed in Amrita Amritapuri campus?          6        3
# 85   Are mobiles allowed in Amrita Amritapuri campus?          6        3
#
#    Ratio Engagement potential Last action Parsed time  \
# 0    1/1                   No    Followed  2020-07-19
# 1    1/1                   No    Followed  2020-07-19
# 2    1/1                   No    Followed  2020-07-19
# 3    1/1                   No    Followed  2020-07-19
# 4    1/1                   No    Followed  2020-06-17
# ..   ...                  ...         ...         ...
# 81   1/3                   No    Followed  2018-04-20
# 82   5/5                   No    Followed  2019-07-29
# 83   5/5                   No    Followed  2019-07-29
# 84   6/3                   No    Followed  2017-06-27
# 85   6/3                   No    Followed  2017-06-27
#
#                                         Question link  \
# 0   https://www.quora.com/Which-is-the-best-of-Amr...
# 1   https://www.quora.com/Which-is-the-best-of-Amr...
# 2   https://www.quora.com/Which-is-the-best-of-Amr...
# 3   https://www.quora.com/Which-is-the-best-of-Amr...
# 4   https://www.quora.com/Will-the-Amrita-entrance...
# ..                                                ...
# 81  https://www.quora.com/What-would-be-a-better-c...
# 82  https://www.quora.com/How-is-life-at-Amrita-Un...
# 83  https://www.quora.com/How-is-life-at-Amrita-Un...
# 84  https://www.quora.com/Are-mobiles-allowed-in-A...
# 85  https://www.quora.com/Are-mobiles-allowed-in-A...
#
#                                               answers  compound Sentiment  \
# 0   Coimbatore is more of a good option but then d...  0.367800  Positive
# 1   Coimbatore is more of a good option but then d...  0.367800  Positive
# 2   Coimbatore is more of a good option but then d...  0.367800  Positive
# 3   Coimbatore is more of a good option but then d...  0.367800  Positive
# 4   Hello there, Amrita entrance has been schedule... -0.074000  Negative
# ..                                                ...       ...       ...
# 81  I would recommend pursuing CSE at the Amritapu...  0.549067  Positive
# 82  Going anonymous for obvious reasons. Well, lif...  0.043238   Neutral
# 83  Life at Amrita University is a mix of both goo...  0.100895  Positive
# 84  I'm currently studying as a first year btech s...  0.320700  Positive
# 85  Yes, but after second year. In first year mobi...  0.042880   Neutral
#
#        score  followers_n
# 0   3.735600         0.05
# 1   3.735600         0.05
# 2   3.735600         0.05
# 3   3.735600         0.05
# 4   2.852000         0.05
# ..       ...          ...
# 81  4.098133         0.05
# 82  3.086477         0.25
# 83  3.201791         0.25
# 84  3.641400         0.30
# 85  3.085760         0.30
#
# [86 rows x 15 columns]

# %%
engagement_median = df['followers_n'].median()
df["engagement"] = df['followers_n'].apply(lambda x: 1 if x >= engagement_median else 0)

# %%
def assignpred(n):
    if n>1 and n<3:
        return max((n-1),1)
    if n>3 and n<5:
        return min((n+1),5)

# %%
df['sentiment_score']=df['score']
df_eng1=df[df.engagement==1]
#if engagement score is greater than the median, increase the positive and negative sentiment
df_eng1['sentiment_score']=df_eng1['score'].apply(lambda x: assignpred(x))
df[df.engagement==1]=df_eng1
df
# Out:
# C:\Users\Kirthika\anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
#     Unnamed: 0                                      Topic  \
# 0            0  Amrita-School-of-Engineering-Amritapuri-1
# 1            1  Amrita-School-of-Engineering-Amritapuri-1
# 2            2        Amrita-University-Amritapuri-Campus
# 3            3        Amrita-University-Amritapuri-Campus
# 4            4  Amrita-School-of-Engineering-Amritapuri-1
# ..         ...                                        ...
# 81          81        Amrita-University-Amritapuri-Campus
# 82          82        Amrita-University-Amritapuri-Campus
# 83          83        Amrita-University-Amritapuri-Campus
# 84          84        Amrita-University-Amritapuri-Campus
# 85          85        Amrita-University-Amritapuri-Campus
#
#                                              question  Followers  Answers  \
# 0   Which is the best of Amrita Amritapuri or Coim...          1        1
# 1   Which is the best of Amrita Amritapuri or Coim...          1        1
# 2   Which is the best of Amrita Amritapuri or Coim...          1        1
# 3   Which is the best of Amrita Amritapuri or Coim...          1        1
# 4   Will the Amrita entrance exam be postponed again?          1        1
# ..                                                ...        ...      ...
# 81  What would be a better choice for somebody who...          1        3
# 82      How is life at Amrita University, Amritapuri?          5        5
# 83      How is life at Amrita University, Amritapuri?          5        5
# 84   Are mobiles allowed in Amrita Amritapuri campus?          6        3
# 85   Are mobiles allowed in Amrita Amritapuri campus?          6        3
#
#    Ratio Engagement potential Last action Parsed time  \
# 0    1/1                   No    Followed  2020-07-19
# 1    1/1                   No    Followed  2020-07-19
# 2    1/1                   No    Followed  2020-07-19
# 3    1/1                   No    Followed  2020-07-19
# 4    1/1                   No    Followed  2020-06-17
# ..   ...                  ...         ...         ...
# 81   1/3                   No    Followed  2018-04-20
# 82   5/5                   No    Followed  2019-07-29
# 83   5/5                   No    Followed  2019-07-29
# 84   6/3                   No    Followed  2017-06-27
# 85   6/3                   No    Followed  2017-06-27
#
#                                         Question link  \
# 0   https://www.quora.com/Which-is-the-best-of-Amr...
# 1   https://www.quora.com/Which-is-the-best-of-Amr...
# 2   https://www.quora.com/Which-is-the-best-of-Amr...
# 3   https://www.quora.com/Which-is-the-best-of-Amr...
# 4   https://www.quora.com/Will-the-Amrita-entrance...
# ..                                                ...
# 81  https://www.quora.com/What-would-be-a-better-c...
# 82  https://www.quora.com/How-is-life-at-Amrita-Un...
# 83  https://www.quora.com/How-is-life-at-Amrita-Un...
# 84  https://www.quora.com/Are-mobiles-allowed-in-A...
# 85  https://www.quora.com/Are-mobiles-allowed-in-A...
#
#                                               answers  compound Sentiment  \
# 0   Coimbatore is more of a good option but then d...  0.367800  Positive
# 1   Coimbatore is more of a good option but then d...  0.367800  Positive
# 2   Coimbatore is more of a good option but then d...  0.367800  Positive
# 3   Coimbatore is more of a good option but then d...  0.367800  Positive
# 4   Hello there, Amrita entrance has been schedule... -0.074000  Negative
# ..                                                ...       ...       ...
# 81  I would recommend pursuing CSE at the Amritapu...  0.549067  Positive
# 82  Going anonymous for obvious reasons. Well, lif...  0.043238   Neutral
# 83  Life at Amrita University is a mix of both goo...  0.100895  Positive
# 84  I'm currently studying as a first year btech s...  0.320700  Positive
# 85  Yes, but after second year. In first year mobi...  0.042880   Neutral
#
#        score  followers_n  engagement  sentiment_score
# 0   3.735600         0.05           0         3.735600
# 1   3.735600         0.05           0         3.735600
# 2   3.735600         0.05           0         3.735600
# 3   3.735600         0.05           0         3.735600
# 4   2.852000         0.05           0         2.852000
# ..       ...          ...         ...              ...
# 81  4.098133         0.05           0         4.098133
# 82  3.086477         0.25           1         4.086477
# 83  3.201791         0.25           1         4.201791
# 84  3.641400         0.30           1         4.641400
# 85  3.085760         0.30           1         4.085760
#
# [86 rows x 17 columns]

# %%
df.rename(columns = {'score':'old_score'}, inplace = True)

# %%
df.to_csv('../../Datasets/Quora/WSA/AmritaQuoraWSA.csv')

# %%
# Out:
#      Unnamed: 0                                 Topic  \
# 388         388  Lovely-Professional-University-LPU-2
# 536         536  Lovely-Professional-University-LPU-2
#
#                                               question  Followers  Answers  \
# 388  How is Sarabjit for Punjabi literature Ias opt...         49        3
# 536  What is Jinsu Bansal’s strategy for the option...         56        3
#
#     Ratio Engagement potential Last action Parsed time  \
# 388  49/3                  Yes    Followed  2020-07-24
# 536  56/3                  Yes    Followed  2020-07-25
#
#                                          Question link answers  followers_n  \
# 388  https://www.quora.com/How-is-Sarabjit-for-Punj...             0.597561
# 536  https://www.quora.com/What-is-Jinsu-Bansal-s-s...             0.682927
#
#      engagement  compound Sentiment old_score sentiment_score
# 388           1      -1.0  Negative         1               1
# 536           1      -1.0  Negative         1               1
