# %%
import json
import csv
#import tweepy
import re
import nltk
from nltk.stem import WordNetLemmatizer
import pandas as pd
#import GetOldTweets3 as got
from nltk.corpus import stopwords
stopwords = set(stopwords.words('english'))
lemmatizer = WordNetLemmatizer()
import numpy as np
from nltk import tokenize
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

# %%
df=pd.read_csv('../../Datasets/Quora/Data/BITSPQuora.csv')

# %%
df
# Out:
#       Unnamed: 0                                              Topic  \
# 0              0  Birla-Institute-of-Technology-and-Science-Pila...
# 1              1  Birla-Institute-of-Technology-and-Science-Pila...
# 2              2  Birla-Institute-of-Technology-and-Science-Pila...
# 3              3  Birla-Institute-of-Technology-and-Science-Pila...
# 4              4  Birla-Institute-of-Technology-and-Science-Pila...
# ...          ...                                                ...
# 2030        2030  Birla-Institute-of-Technology-and-Science-Pila...
# 2031        2031  Birla-Institute-of-Technology-and-Science-Pila...
# 2032        2032  Birla-Institute-of-Technology-and-Science-Pila...
# 2033        2033  Birla-Institute-of-Technology-and-Science-Pila...
# 2034        2034  Birla-Institute-of-Technology-and-Science-Pila...
#
#                                                question  Followers  Answers  \
# 0     What made BITS Pilani so good? How did it mana...          2        2
# 1     What made BITS Pilani so good? How did it mana...          2        2
# 2     Which is better, BITS Pilani Microelectronics ...          5        2
# 3     Which is better, BITS Pilani Microelectronics ...          5        2
# 4     Which is better to get into, BITS Pilani DUBAI...          1        1
# ...                                                 ...        ...      ...
# 2030  Does it even make sense to expect any drop in ...         30        2
# 2031  What are the chances of me getting an MSc. in ...         10        4
# 2032  What are the chances of me getting an MSc. in ...         10        4
# 2033  What is BITS Pilani's cutoff after the 4th ite...         42        2
# 2034  What is BITS Pilani's cutoff after the 4th ite...         42        2
#
#      Ratio Engagement potential Last action Parsed time  \
# 0      2/2                   No    Followed  2020-07-24
# 1      2/2                   No    Followed  2020-07-24
# 2      5/2                   No    Followed  2020-07-20
# 3      5/2                   No    Followed  2020-07-20
# 4      1/1                   No    Followed  2020-07-19
# ...    ...                  ...         ...         ...
# 2030  30/2                  Yes    Followed  2018-07-26
# 2031  10/4                   No    Followed  2018-07-21
# 2032  10/4                   No    Followed  2018-07-21
# 2033  42/2                  Yes    Followed  2018-07-20
# 2034  42/2                  Yes    Followed  2018-07-20
#
#                                           Question link  \
# 0     https://www.quora.com/What-made-BITS-Pilani-so...
# 1     https://www.quora.com/What-made-BITS-Pilani-so...
# 2     https://www.quora.com/Which-is-better-BITS-Pil...
# 3     https://www.quora.com/Which-is-better-BITS-Pil...
# 4     https://www.quora.com/Which-is-better-to-get-i...
# ...                                                 ...
# 2030  https://www.quora.com/Does-it-even-make-sense-...
# 2031  https://www.quora.com/What-are-the-chances-of-...
# 2032  https://www.quora.com/What-are-the-chances-of-...
# 2033  https://www.quora.com/What-is-BITS-Pilanis-cut...
# 2034  https://www.quora.com/What-is-BITS-Pilanis-cut...
#
#                                                 answers
# 0     Thanks for A2A What makes a college good in ge...
# 1     Andhon mein kana, Raja ! This is the proverb t...
# 2     This correct answer is in Indian context: Sinc...
# 3     Obviously BITS Microelectronics. BITS is the f...
# 4     It's absolute foolishness to compare IITs with...
# ...                                                 ...
# 2030  Thanks for A2A!!!! Well, You don’t know what i...
# 2031  Hey! Observing the last year's cutoffs for Msc...
# 2032  The chances are slim as the cutoff for the 4th...
# 2033  These are most accurate cutoff for 2019 so far...
# 2034  Please join BITSAT Queries group on FB you'll ...
#
# [2035 rows x 11 columns]

# %%
df=df.reset_index()

# %%
df=df.drop_duplicates()

# %%
df=df.drop(['index'],axis=1)

# %%
def vader_score(paragraph):
    analyzer = SentimentIntensityAnalyzer()
    paragraphSentiments = 0.0
    avg = -1
    sentence_list = tokenize.sent_tokenize(paragraph)
    size = len(sentence_list)
    #print(len((sentence_list))
    for sentence in sentence_list :
        vs = analyzer.polarity_scores(sentence)
        paragraphSentiments += vs["compound"]
    if( size == 0):
        print("zero")
    else:
        avg = (paragraphSentiments / size)
    return avg
df['compound'] = df['answers'].apply(lambda x: vader_score(x))
# Out:
# zero
# zero
# zero

# %%
i = df[df['compound'] == -1].index
df.drop(i)
# Out:
#       Unnamed: 0                                              Topic  \
# 0              0  Birla-Institute-of-Technology-and-Science-Pila...
# 1              1  Birla-Institute-of-Technology-and-Science-Pila...
# 2              2  Birla-Institute-of-Technology-and-Science-Pila...
# 3              3  Birla-Institute-of-Technology-and-Science-Pila...
# 4              4  Birla-Institute-of-Technology-and-Science-Pila...
# ...          ...                                                ...
# 2030        2030  Birla-Institute-of-Technology-and-Science-Pila...
# 2031        2031  Birla-Institute-of-Technology-and-Science-Pila...
# 2032        2032  Birla-Institute-of-Technology-and-Science-Pila...
# 2033        2033  Birla-Institute-of-Technology-and-Science-Pila...
# 2034        2034  Birla-Institute-of-Technology-and-Science-Pila...
#
#                                                question  Followers  Answers  \
# 0     What made BITS Pilani so good? How did it mana...          2        2
# 1     What made BITS Pilani so good? How did it mana...          2        2
# 2     Which is better, BITS Pilani Microelectronics ...          5        2
# 3     Which is better, BITS Pilani Microelectronics ...          5        2
# 4     Which is better to get into, BITS Pilani DUBAI...          1        1
# ...                                                 ...        ...      ...
# 2030  Does it even make sense to expect any drop in ...         30        2
# 2031  What are the chances of me getting an MSc. in ...         10        4
# 2032  What are the chances of me getting an MSc. in ...         10        4
# 2033  What is BITS Pilani's cutoff after the 4th ite...         42        2
# 2034  What is BITS Pilani's cutoff after the 4th ite...         42        2
#
#      Ratio Engagement potential Last action Parsed time  \
# 0      2/2                   No    Followed  2020-07-24
# 1      2/2                   No    Followed  2020-07-24
# 2      5/2                   No    Followed  2020-07-20
# 3      5/2                   No    Followed  2020-07-20
# 4      1/1                   No    Followed  2020-07-19
# ...    ...                  ...         ...         ...
# 2030  30/2                  Yes    Followed  2018-07-26
# 2031  10/4                   No    Followed  2018-07-21
# 2032  10/4                   No    Followed  2018-07-21
# 2033  42/2                  Yes    Followed  2018-07-20
# 2034  42/2                  Yes    Followed  2018-07-20
#
#                                           Question link  \
# 0     https://www.quora.com/What-made-BITS-Pilani-so...
# 1     https://www.quora.com/What-made-BITS-Pilani-so...
# 2     https://www.quora.com/Which-is-better-BITS-Pil...
# 3     https://www.quora.com/Which-is-better-BITS-Pil...
# 4     https://www.quora.com/Which-is-better-to-get-i...
# ...                                                 ...
# 2030  https://www.quora.com/Does-it-even-make-sense-...
# 2031  https://www.quora.com/What-are-the-chances-of-...
# 2032  https://www.quora.com/What-are-the-chances-of-...
# 2033  https://www.quora.com/What-is-BITS-Pilanis-cut...
# 2034  https://www.quora.com/What-is-BITS-Pilanis-cut...
#
#                                                 answers  compound
# 0     Thanks for A2A What makes a college good in ge...  0.317933
# 1     Andhon mein kana, Raja ! This is the proverb t...  0.010486
# 2     This correct answer is in Indian context: Sinc... -0.274367
# 3     Obviously BITS Microelectronics. BITS is the f...  0.144467
# 4     It's absolute foolishness to compare IITs with...  0.128200
# ...                                                 ...       ...
# 2030  Thanks for A2A!!!! Well, You don’t know what i...  0.147786
# 2031  Hey! Observing the last year's cutoffs for Msc...  0.297362
# 2032  The chances are slim as the cutoff for the 4th...  0.254600
# 2033  These are most accurate cutoff for 2019 so far...  0.177900
# 2034  Please join BITSAT Queries group on FB you'll ...  0.542300
#
# [2032 rows x 12 columns]

# %%
#classifying sentiments as positive,negative and neutral
def sentiment(compound):
    res = ""
    if(compound >= 0.05):
        res="Positive"
    elif(compound <= - 0.05):
        res="Negative"
    else:
        res="Neutral"
    return res

df['Sentiment'] = df['compound'].apply(lambda x: sentiment(x))

# %%
df
# Out:
#       Unnamed: 0                                              Topic  \
# 0              0  Birla-Institute-of-Technology-and-Science-Pila...
# 1              1  Birla-Institute-of-Technology-and-Science-Pila...
# 2              2  Birla-Institute-of-Technology-and-Science-Pila...
# 3              3  Birla-Institute-of-Technology-and-Science-Pila...
# 4              4  Birla-Institute-of-Technology-and-Science-Pila...
# ...          ...                                                ...
# 2030        2030  Birla-Institute-of-Technology-and-Science-Pila...
# 2031        2031  Birla-Institute-of-Technology-and-Science-Pila...
# 2032        2032  Birla-Institute-of-Technology-and-Science-Pila...
# 2033        2033  Birla-Institute-of-Technology-and-Science-Pila...
# 2034        2034  Birla-Institute-of-Technology-and-Science-Pila...
#
#                                                question  Followers  Answers  \
# 0     What made BITS Pilani so good? How did it mana...          2        2
# 1     What made BITS Pilani so good? How did it mana...          2        2
# 2     Which is better, BITS Pilani Microelectronics ...          5        2
# 3     Which is better, BITS Pilani Microelectronics ...          5        2
# 4     Which is better to get into, BITS Pilani DUBAI...          1        1
# ...                                                 ...        ...      ...
# 2030  Does it even make sense to expect any drop in ...         30        2
# 2031  What are the chances of me getting an MSc. in ...         10        4
# 2032  What are the chances of me getting an MSc. in ...         10        4
# 2033  What is BITS Pilani's cutoff after the 4th ite...         42        2
# 2034  What is BITS Pilani's cutoff after the 4th ite...         42        2
#
#      Ratio Engagement potential Last action Parsed time  \
# 0      2/2                   No    Followed  2020-07-24
# 1      2/2                   No    Followed  2020-07-24
# 2      5/2                   No    Followed  2020-07-20
# 3      5/2                   No    Followed  2020-07-20
# 4      1/1                   No    Followed  2020-07-19
# ...    ...                  ...         ...         ...
# 2030  30/2                  Yes    Followed  2018-07-26
# 2031  10/4                   No    Followed  2018-07-21
# 2032  10/4                   No    Followed  2018-07-21
# 2033  42/2                  Yes    Followed  2018-07-20
# 2034  42/2                  Yes    Followed  2018-07-20
#
#                                           Question link  \
# 0     https://www.quora.com/What-made-BITS-Pilani-so...
# 1     https://www.quora.com/What-made-BITS-Pilani-so...
# 2     https://www.quora.com/Which-is-better-BITS-Pil...
# 3     https://www.quora.com/Which-is-better-BITS-Pil...
# 4     https://www.quora.com/Which-is-better-to-get-i...
# ...                                                 ...
# 2030  https://www.quora.com/Does-it-even-make-sense-...
# 2031  https://www.quora.com/What-are-the-chances-of-...
# 2032  https://www.quora.com/What-are-the-chances-of-...
# 2033  https://www.quora.com/What-is-BITS-Pilanis-cut...
# 2034  https://www.quora.com/What-is-BITS-Pilanis-cut...
#
#                                                 answers  compound Sentiment
# 0     Thanks for A2A What makes a college good in ge...  0.317933  Positive
# 1     Andhon mein kana, Raja ! This is the proverb t...  0.010486   Neutral
# 2     This correct answer is in Indian context: Sinc... -0.274367  Negative
# 3     Obviously BITS Microelectronics. BITS is the f...  0.144467  Positive
# 4     It's absolute foolishness to compare IITs with...  0.128200  Positive
# ...                                                 ...       ...       ...
# 2030  Thanks for A2A!!!! Well, You don’t know what i...  0.147786  Positive
# 2031  Hey! Observing the last year's cutoffs for Msc...  0.297362  Positive
# 2032  The chances are slim as the cutoff for the 4th...  0.254600  Positive
# 2033  These are most accurate cutoff for 2019 so far...  0.177900  Positive
# 2034  Please join BITSAT Queries group on FB you'll ...  0.542300  Positive
#
# [2035 rows x 13 columns]

# %%
def convert(score):
    OldRange = 2  
    NewRange = 4  
    NewValue = (((score + 1) * NewRange) / OldRange) + 1
    return NewValue
df['score'] = df['compound'].apply(lambda x: convert(x))
df
def assignpred(n):
    if n>1 and n<2.9:
        return max((n-1),1)
    if n>3.1 and n<5:
        return min((n+1),5)
    else:
        return n

# %%
def normalize(feature):
    max_value = df[feature].max()
    min_value = df[feature].min()
    result = (df[feature] - min_value) / (max_value - min_value)
    return result

# %%
df['followers_n']=normalize('Followers')

# %%
df
# Out:
#       Unnamed: 0                                              Topic  \
# 0              0  Birla-Institute-of-Technology-and-Science-Pila...
# 1              1  Birla-Institute-of-Technology-and-Science-Pila...
# 2              2  Birla-Institute-of-Technology-and-Science-Pila...
# 3              3  Birla-Institute-of-Technology-and-Science-Pila...
# 4              4  Birla-Institute-of-Technology-and-Science-Pila...
# ...          ...                                                ...
# 2030        2030  Birla-Institute-of-Technology-and-Science-Pila...
# 2031        2031  Birla-Institute-of-Technology-and-Science-Pila...
# 2032        2032  Birla-Institute-of-Technology-and-Science-Pila...
# 2033        2033  Birla-Institute-of-Technology-and-Science-Pila...
# 2034        2034  Birla-Institute-of-Technology-and-Science-Pila...
#
#                                                question  Followers  Answers  \
# 0     What made BITS Pilani so good? How did it mana...          2        2
# 1     What made BITS Pilani so good? How did it mana...          2        2
# 2     Which is better, BITS Pilani Microelectronics ...          5        2
# 3     Which is better, BITS Pilani Microelectronics ...          5        2
# 4     Which is better to get into, BITS Pilani DUBAI...          1        1
# ...                                                 ...        ...      ...
# 2030  Does it even make sense to expect any drop in ...         30        2
# 2031  What are the chances of me getting an MSc. in ...         10        4
# 2032  What are the chances of me getting an MSc. in ...         10        4
# 2033  What is BITS Pilani's cutoff after the 4th ite...         42        2
# 2034  What is BITS Pilani's cutoff after the 4th ite...         42        2
#
#      Ratio Engagement potential Last action Parsed time  \
# 0      2/2                   No    Followed  2020-07-24
# 1      2/2                   No    Followed  2020-07-24
# 2      5/2                   No    Followed  2020-07-20
# 3      5/2                   No    Followed  2020-07-20
# 4      1/1                   No    Followed  2020-07-19
# ...    ...                  ...         ...         ...
# 2030  30/2                  Yes    Followed  2018-07-26
# 2031  10/4                   No    Followed  2018-07-21
# 2032  10/4                   No    Followed  2018-07-21
# 2033  42/2                  Yes    Followed  2018-07-20
# 2034  42/2                  Yes    Followed  2018-07-20
#
#                                           Question link  \
# 0     https://www.quora.com/What-made-BITS-Pilani-so...
# 1     https://www.quora.com/What-made-BITS-Pilani-so...
# 2     https://www.quora.com/Which-is-better-BITS-Pil...
# 3     https://www.quora.com/Which-is-better-BITS-Pil...
# 4     https://www.quora.com/Which-is-better-to-get-i...
# ...                                                 ...
# 2030  https://www.quora.com/Does-it-even-make-sense-...
# 2031  https://www.quora.com/What-are-the-chances-of-...
# 2032  https://www.quora.com/What-are-the-chances-of-...
# 2033  https://www.quora.com/What-is-BITS-Pilanis-cut...
# 2034  https://www.quora.com/What-is-BITS-Pilanis-cut...
#
#                                                 answers  compound Sentiment  \
# 0     Thanks for A2A What makes a college good in ge...  0.317933  Positive
# 1     Andhon mein kana, Raja ! This is the proverb t...  0.010486   Neutral
# 2     This correct answer is in Indian context: Sinc... -0.274367  Negative
# 3     Obviously BITS Microelectronics. BITS is the f...  0.144467  Positive
# 4     It's absolute foolishness to compare IITs with...  0.128200  Positive
# ...                                                 ...       ...       ...
# 2030  Thanks for A2A!!!! Well, You don’t know what i...  0.147786  Positive
# 2031  Hey! Observing the last year's cutoffs for Msc...  0.297362  Positive
# 2032  The chances are slim as the cutoff for the 4th...  0.254600  Positive
# 2033  These are most accurate cutoff for 2019 so far...  0.177900  Positive
# 2034  Please join BITSAT Queries group on FB you'll ...  0.542300  Positive
#
#          score  followers_n
# 0     3.635867     0.011696
# 1     3.020971     0.011696
# 2     2.451267     0.029240
# 3     3.288933     0.029240
# 4     3.256400     0.005848
# ...        ...          ...
# 2030  3.295571     0.175439
# 2031  3.594725     0.058480
# 2032  3.509200     0.058480
# 2033  3.355800     0.245614
# 2034  4.084600     0.245614
#
# [2035 rows x 15 columns]

# %%
engagement_median = df['followers_n'].median()
df["engagement"] = df['followers_n'].apply(lambda x: 1 if x >= engagement_median else 0)

# %%
df['sentiment_score']=df['score']
df_eng1=df[df.engagement==1]
#if engagement score is greater than the median, increase the positive and negative sentiment
df_eng1['sentiment_score']=df_eng1['score'].apply(lambda x: assignpred(x))
df[df.engagement==1]=df_eng1
df
# Out:
# C:\Users\Kirthika\anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
#       Unnamed: 0                                              Topic  \
# 0              0  Birla-Institute-of-Technology-and-Science-Pila...
# 1              1  Birla-Institute-of-Technology-and-Science-Pila...
# 2              2  Birla-Institute-of-Technology-and-Science-Pila...
# 3              3  Birla-Institute-of-Technology-and-Science-Pila...
# 4              4  Birla-Institute-of-Technology-and-Science-Pila...
# ...          ...                                                ...
# 2030        2030  Birla-Institute-of-Technology-and-Science-Pila...
# 2031        2031  Birla-Institute-of-Technology-and-Science-Pila...
# 2032        2032  Birla-Institute-of-Technology-and-Science-Pila...
# 2033        2033  Birla-Institute-of-Technology-and-Science-Pila...
# 2034        2034  Birla-Institute-of-Technology-and-Science-Pila...
#
#                                                question  Followers  Answers  \
# 0     What made BITS Pilani so good? How did it mana...          2        2
# 1     What made BITS Pilani so good? How did it mana...          2        2
# 2     Which is better, BITS Pilani Microelectronics ...          5        2
# 3     Which is better, BITS Pilani Microelectronics ...          5        2
# 4     Which is better to get into, BITS Pilani DUBAI...          1        1
# ...                                                 ...        ...      ...
# 2030  Does it even make sense to expect any drop in ...         30        2
# 2031  What are the chances of me getting an MSc. in ...         10        4
# 2032  What are the chances of me getting an MSc. in ...         10        4
# 2033  What is BITS Pilani's cutoff after the 4th ite...         42        2
# 2034  What is BITS Pilani's cutoff after the 4th ite...         42        2
#
#      Ratio Engagement potential Last action Parsed time  \
# 0      2/2                   No    Followed  2020-07-24
# 1      2/2                   No    Followed  2020-07-24
# 2      5/2                   No    Followed  2020-07-20
# 3      5/2                   No    Followed  2020-07-20
# 4      1/1                   No    Followed  2020-07-19
# ...    ...                  ...         ...         ...
# 2030  30/2                  Yes    Followed  2018-07-26
# 2031  10/4                   No    Followed  2018-07-21
# 2032  10/4                   No    Followed  2018-07-21
# 2033  42/2                  Yes    Followed  2018-07-20
# 2034  42/2                  Yes    Followed  2018-07-20
#
#                                           Question link  \
# 0     https://www.quora.com/What-made-BITS-Pilani-so...
# 1     https://www.quora.com/What-made-BITS-Pilani-so...
# 2     https://www.quora.com/Which-is-better-BITS-Pil...
# 3     https://www.quora.com/Which-is-better-BITS-Pil...
# 4     https://www.quora.com/Which-is-better-to-get-i...
# ...                                                 ...
# 2030  https://www.quora.com/Does-it-even-make-sense-...
# 2031  https://www.quora.com/What-are-the-chances-of-...
# 2032  https://www.quora.com/What-are-the-chances-of-...
# 2033  https://www.quora.com/What-is-BITS-Pilanis-cut...
# 2034  https://www.quora.com/What-is-BITS-Pilanis-cut...
#
#                                                 answers  compound Sentiment  \
# 0     Thanks for A2A What makes a college good in ge...  0.317933  Positive
# 1     Andhon mein kana, Raja ! This is the proverb t...  0.010486   Neutral
# 2     This correct answer is in Indian context: Sinc... -0.274367  Negative
# 3     Obviously BITS Microelectronics. BITS is the f...  0.144467  Positive
# 4     It's absolute foolishness to compare IITs with...  0.128200  Positive
# ...                                                 ...       ...       ...
# 2030  Thanks for A2A!!!! Well, You don’t know what i...  0.147786  Positive
# 2031  Hey! Observing the last year's cutoffs for Msc...  0.297362  Positive
# 2032  The chances are slim as the cutoff for the 4th...  0.254600  Positive
# 2033  These are most accurate cutoff for 2019 so far...  0.177900  Positive
# 2034  Please join BITSAT Queries group on FB you'll ...  0.542300  Positive
#
#          score  followers_n  engagement  sentiment_score
# 0     3.635867     0.011696           0         3.635867
# 1     3.020971     0.011696           0         3.020971
# 2     2.451267     0.029240           1         1.451267
# 3     3.288933     0.029240           1         4.288933
# 4     3.256400     0.005848           0         3.256400
# ...        ...          ...         ...              ...
# 2030  3.295571     0.175439           1         4.295571
# 2031  3.594725     0.058480           1         4.594725
# 2032  3.509200     0.058480           1         4.509200
# 2033  3.355800     0.245614           1         4.355800
# 2034  4.084600     0.245614           1         5.000000
#
# [2035 rows x 17 columns]

# %%
df.rename(columns = {'score':'old_score'}, inplace = True)

# %%
df.dropna()
# Out:
#       Unnamed: 0                                              Topic  \
# 0              0  Birla-Institute-of-Technology-and-Science-Pila...
# 1              1  Birla-Institute-of-Technology-and-Science-Pila...
# 2              2  Birla-Institute-of-Technology-and-Science-Pila...
# 3              3  Birla-Institute-of-Technology-and-Science-Pila...
# 4              4  Birla-Institute-of-Technology-and-Science-Pila...
# ...          ...                                                ...
# 2030        2030  Birla-Institute-of-Technology-and-Science-Pila...
# 2031        2031  Birla-Institute-of-Technology-and-Science-Pila...
# 2032        2032  Birla-Institute-of-Technology-and-Science-Pila...
# 2033        2033  Birla-Institute-of-Technology-and-Science-Pila...
# 2034        2034  Birla-Institute-of-Technology-and-Science-Pila...
#
#                                                question  Followers  Answers  \
# 0     What made BITS Pilani so good? How did it mana...          2        2
# 1     What made BITS Pilani so good? How did it mana...          2        2
# 2     Which is better, BITS Pilani Microelectronics ...          5        2
# 3     Which is better, BITS Pilani Microelectronics ...          5        2
# 4     Which is better to get into, BITS Pilani DUBAI...          1        1
# ...                                                 ...        ...      ...
# 2030  Does it even make sense to expect any drop in ...         30        2
# 2031  What are the chances of me getting an MSc. in ...         10        4
# 2032  What are the chances of me getting an MSc. in ...         10        4
# 2033  What is BITS Pilani's cutoff after the 4th ite...         42        2
# 2034  What is BITS Pilani's cutoff after the 4th ite...         42        2
#
#      Ratio Engagement potential Last action Parsed time  \
# 0      2/2                   No    Followed  2020-07-24
# 1      2/2                   No    Followed  2020-07-24
# 2      5/2                   No    Followed  2020-07-20
# 3      5/2                   No    Followed  2020-07-20
# 4      1/1                   No    Followed  2020-07-19
# ...    ...                  ...         ...         ...
# 2030  30/2                  Yes    Followed  2018-07-26
# 2031  10/4                   No    Followed  2018-07-21
# 2032  10/4                   No    Followed  2018-07-21
# 2033  42/2                  Yes    Followed  2018-07-20
# 2034  42/2                  Yes    Followed  2018-07-20
#
#                                           Question link  \
# 0     https://www.quora.com/What-made-BITS-Pilani-so...
# 1     https://www.quora.com/What-made-BITS-Pilani-so...
# 2     https://www.quora.com/Which-is-better-BITS-Pil...
# 3     https://www.quora.com/Which-is-better-BITS-Pil...
# 4     https://www.quora.com/Which-is-better-to-get-i...
# ...                                                 ...
# 2030  https://www.quora.com/Does-it-even-make-sense-...
# 2031  https://www.quora.com/What-are-the-chances-of-...
# 2032  https://www.quora.com/What-are-the-chances-of-...
# 2033  https://www.quora.com/What-is-BITS-Pilanis-cut...
# 2034  https://www.quora.com/What-is-BITS-Pilanis-cut...
#
#                                                 answers  compound Sentiment  \
# 0     Thanks for A2A What makes a college good in ge...  0.317933  Positive
# 1     Andhon mein kana, Raja ! This is the proverb t...  0.010486   Neutral
# 2     This correct answer is in Indian context: Sinc... -0.274367  Negative
# 3     Obviously BITS Microelectronics. BITS is the f...  0.144467  Positive
# 4     It's absolute foolishness to compare IITs with...  0.128200  Positive
# ...                                                 ...       ...       ...
# 2030  Thanks for A2A!!!! Well, You don’t know what i...  0.147786  Positive
# 2031  Hey! Observing the last year's cutoffs for Msc...  0.297362  Positive
# 2032  The chances are slim as the cutoff for the 4th...  0.254600  Positive
# 2033  These are most accurate cutoff for 2019 so far...  0.177900  Positive
# 2034  Please join BITSAT Queries group on FB you'll ...  0.542300  Positive
#
#       old_score  followers_n  engagement  sentiment_score
# 0      3.635867     0.011696           0         3.635867
# 1      3.020971     0.011696           0         3.020971
# 2      2.451267     0.029240           1         1.451267
# 3      3.288933     0.029240           1         4.288933
# 4      3.256400     0.005848           0         3.256400
# ...         ...          ...         ...              ...
# 2030   3.295571     0.175439           1         4.295571
# 2031   3.594725     0.058480           1         4.594725
# 2032   3.509200     0.058480           1         4.509200
# 2033   3.355800     0.245614           1         4.355800
# 2034   4.084600     0.245614           1         5.000000
#
# [2035 rows x 17 columns]

# %%
df.to_csv('../../Datasets/Quora/WSA/BITSPQuoraWSA.csv')
